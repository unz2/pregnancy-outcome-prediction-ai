# %%
import pandas as pd
import numpy as np
import random
import os
from autogluon.tabular import TabularPredictor
import warnings

# 경고 무시
warnings.filterwarnings('ignore')

# ==========================================
# 0. 시드 고정
# ==========================================
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42)

# ==========================================
# 1. 데이터 로드
# ==========================================
train_df = pd.read_csv('../Data/train.csv')
test_df = pd.read_csv('../Data/test.csv')
target = '임신 성공 여부'

# ==========================================
# 2. 파생변수 생성 (Feature Engineering)
# ==========================================

def feature_engineering(df):
    df = df.copy()

    # A. 나이 
    age_map = {
        '만18-34세': 2, '만35-37세': 3, '만38-39세': 4, 
        '만40-42세': 5, '만43-44세': 6, '만45-50세': 7, 
        '알 수 없음': 1 # 결측은 별도 범주로
    }
    df['시술 당시 나이'] = df['시술 당시 나이'].map(age_map).fillna(0)
    
    # B. 배아 퀄리티 추정 지표
    if '총 생성 배아 수' in df.columns and '이식된 배아 수' in df.columns:
        df['배아_이식_효율'] = df['이식된 배아 수'] / (df['총 생성 배아 수'] + 1e-6)
        
    # C. 미세주입 효율 (ICSI)
    if '미세주입된 난자 수' in df.columns and '미세주입에서 생성된 배아 수' in df.columns:
        df['미세주입_수정률'] = df['미세주입에서 생성된 배아 수'] / (df['미세주입된 난자 수'] + 1e-6)
        
    # D. 나이 보정 이식 수 (나이가 많을수록 이식을 많이 시도하는 경향 보정)
    df['나이_대비_이식수'] = df['시술 당시 나이'] * df['이식된 배아 수']

    # E. 불필요한 컬럼 삭제 
    drop_cols = ['ID', '시술 시기 코드'] 
    df = df.drop(drop_cols, axis=1)

    return df

# 전처리 적용
train_df = feature_engineering(train_df)
test_df = feature_engineering(test_df)

# ==========================================
# 4. 모델 학습
# ==========================================

predictor = TabularPredictor(
    label=target,
    eval_metric='roc_auc', 
    path='ag_models_final',
    problem_type='binary'
).fit(
    train_data=train_df,
    presets='best_quality', 
    num_stack_levels=1, 
    num_bag_folds=5,
    time_limit=3600 * 2,
    included_model_types=['GBM', 'CAT', 'XGB', 'RF', 'XT'],
)


# ==========================================
# 5. 추론 및 저장
# ==========================================
pred_probs = predictor.predict_proba(test_df)
final_probs = pred_probs.iloc[:, 1]

# ==========================================
# 5. 리더보드 (학습 데이터 내에서의 Validation Score 확인)
# ==========================================
lb = predictor.leaderboard(train_df, silent=True)
display(lb.head())
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="ag_models_final"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.11.14
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 25.2.0: Tue Nov 18 21:09:40 PST 2025; root:xnu-12377.61.12~1/RELEASE_ARM64_T6000
# CPU Count:          10
# Pytorch Version:    2.9.1
# CUDA Version:       CUDA is not available
# GPU Count:          WARNING: Exception was raised when calculating GPU count (AssertionError)
# Memory Avail:       7.04 GB / 16.00 GB (44.0%)
# Disk Space Avail:   179.41 GB / 460.43 GB (39.0%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 1800s of the 7200s of remaining time (25%).
# DyStack: Disabling memory safe fit mode in DyStack because GPUs were detected and num_gpus='auto' (GPUs cannot be used in memory safe fit mode). If you want to use memory safe fit mode, manually set `num_gpus=0`.
# Running DyStack sub-fit ...
# Beginning AutoGluon training ... Time limit = 1800s
# AutoGluon will save models to "/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_final/ds_sub_fit/sub_fit_ho"
# Train Data Rows:    227867
# Train Data Columns: 69
# Label Column:       임신 성공 여부
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7513.31 MB
# 	Train Data (Original)  Memory Usage: 425.20 MB (5.7% of available memory)
# 	Warning: Data size prior to feature transformation consumes 5.7% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 22 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 1): ['불임 원인 - 여성 요인']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 2): ['불임 원인 - 정자 면역학적 요인', '불임 원인 - 정자 운동성']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('int', []) : 2 | ['불임 원인 - 정자 면역학적 요인', '불임 원인 - 정자 운동성']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 32 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 검사 사용 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', ...]
# 		('int', [])    : 16 | ['시술 당시 나이', '배란 자극 여부', '남성 주 불임 원인', '남성 부 불임 원인', '여성 주 불임 원인', ...]
# 		('object', []) : 18 | ['시술 유형', '특정 시술 유형', '배란 유도 유형', '배아 생성 주요 이유', '총 시술 횟수', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 17 | ['특정 시술 유형', '배란 유도 유형', '배아 생성 주요 이유', '총 시술 횟수', '클리닉 내 총 시술 횟수', ...]
# 		('float', [])     : 28 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', '미세주입된 난자 수', ...]
# 		('int', [])       :  1 | ['시술 당시 나이']
# 		('int', ['bool']) : 20 | ['시술 유형', '배란 자극 여부', '착상 전 유전 검사 사용 여부', '남성 주 불임 원인', '남성 부 불임 원인', ...]
# 	1.3s = Fit runtime
# 	66 features in original data used to generate 66 features in processed data.
# 	Train Data (Processed) Memory Usage: 58.46 MB (0.8% of available memory)
# Data preprocessing and feature engineering runtime = 1.41s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Included models: ['GBM', 'CAT', 'XGB', 'RF', 'XT'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 64 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1198.76s of the 1798.58s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.09%)
# 	0.7384	 = Validation score   (roc_auc)
# 	5.18s	 = Training   runtime
# 	1.75s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1189.35s of the 1789.17s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.16%)
# 	0.7383	 = Validation score   (roc_auc)
# 	3.85s	 = Training   runtime
# 	1.12s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1183.62s of the 1783.44s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/6.7 GB
# 	0.7262	 = Validation score   (roc_auc)
# 	9.41s	 = Training   runtime
# 	6.01s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1167.79s of the 1767.61s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/6.3 GB
# 	0.7274	 = Validation score   (roc_auc)
# 	9.68s	 = Training   runtime
# 	6.09s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1151.61s of the 1751.44s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=13.22%)
# 	0.7388	 = Validation score   (roc_auc)
# 	1523.42s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 226.33s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.0/6.3 GB
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.476, 'LightGBMXT_BAG_L1': 0.238, 'LightGBM_BAG_L1': 0.238, 'RandomForestEntr_BAG_L1': 0.048}
# 	0.7391	 = Validation score   (roc_auc)
# 	3.45s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Included models: ['GBM', 'CAT', 'XGB', 'RF', 'XT'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 64 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 222.84s of the 222.81s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.15%)
# 	0.7384	 = Validation score   (roc_auc)
# 	3.44s	 = Training   runtime
# 	0.75s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 216.16s of the 216.13s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.00%)
# 	0.7339	 = Validation score   (roc_auc)
# 	971.67s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -757.29s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.0/5.8 GB
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.375, 'LightGBM_BAG_L2': 0.208, 'LightGBMXT_BAG_L1': 0.167, 'LightGBM_BAG_L1': 0.167, 'RandomForestEntr_BAG_L1': 0.042, 'LightGBMXT_BAG_L2': 0.042}
# 	0.7391	 = Validation score   (roc_auc)
# 	4.69s	 = Training   runtime
# 	0.03s	 = Validation runtime
# AutoGluon training complete, total runtime = 2562.05s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 10530.6 rows/s (45574 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_final/ds_sub_fit/sub_fit_ho")
# Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                      model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3       0.742142   0.739134     roc_auc        1.797746      16.110152  2531.332702                 0.003243                0.027229           4.688018            3       True          9
# 1      WeightedEnsemble_L2       0.742108   0.739142     roc_auc        1.217592       9.220003  1545.583364                 0.001651                0.027194           3.453729            2       True          6
# 2          CatBoost_BAG_L1       0.742043   0.738762     roc_auc        0.158117       0.233614  1523.418723                 0.158117                0.233614        1523.418723            1       True          5
# 3        LightGBMXT_BAG_L2       0.741927   0.738439     roc_auc        1.756935      15.951202  1554.976196                 0.146464                0.747676           3.437015            2       True          7
# 4        LightGBMXT_BAG_L1       0.741852   0.738398     roc_auc        0.433013       1.751477     5.183472                 0.433013                1.751477           5.183472            1       True          1
# 5          LightGBM_BAG_L2       0.741769   0.733922     roc_auc        1.648039      15.335247  2523.207669                 0.037568                0.131722         971.668488            2       True          8
# 6          LightGBM_BAG_L1       0.740850   0.738325     roc_auc        0.204053       1.119611     3.848021                 0.204053                1.119611           3.848021            1       True          2
# 7  RandomForestEntr_BAG_L1       0.732668   0.727407     roc_auc        0.420758       6.088106     9.679419                 0.420758                6.088106           9.679419            1       True          4
# 8  RandomForestGini_BAG_L1       0.731093   0.726179     roc_auc        0.394530       6.010717     9.409546                 0.394530                6.010717           9.409546            1       True          3
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	2565s	 = DyStack   runtime |	4635s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 4635s
# AutoGluon will save models to "/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_final"
# Train Data Rows:    256351
# Train Data Columns: 69
# Label Column:       임신 성공 여부
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7147.66 MB
# 	Train Data (Original)  Memory Usage: 515.53 MB (7.2% of available memory)
# 	Warning: Data size prior to feature transformation consumes 7.2% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 22 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 1): ['불임 원인 - 여성 요인']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 1): ['불임 원인 - 정자 면역학적 요인']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('int', []) : 1 | ['불임 원인 - 정자 면역학적 요인']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 32 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 검사 사용 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', ...]
# 		('int', [])    : 17 | ['시술 당시 나이', '배란 자극 여부', '남성 주 불임 원인', '남성 부 불임 원인', '여성 주 불임 원인', ...]
# 		('object', []) : 18 | ['시술 유형', '특정 시술 유형', '배란 유도 유형', '배아 생성 주요 이유', '총 시술 횟수', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 17 | ['특정 시술 유형', '배란 유도 유형', '배아 생성 주요 이유', '총 시술 횟수', '클리닉 내 총 시술 횟수', ...]
# 		('float', [])     : 28 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', '미세주입된 난자 수', ...]
# 		('int', [])       :  1 | ['시술 당시 나이']
# 		('int', ['bool']) : 21 | ['시술 유형', '배란 자극 여부', '착상 전 유전 검사 사용 여부', '남성 주 불임 원인', '남성 부 불임 원인', ...]
# 	1.7s = Fit runtime
# 	67 features in original data used to generate 67 features in processed data.
# 	Train Data (Processed) Memory Usage: 66.02 MB (0.9% of available memory)
# Data preprocessing and feature engineering runtime = 1.87s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Included models: ['GBM', 'CAT', 'XGB', 'RF', 'XT'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 64 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3087.77s of the 4632.81s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.01%)
# 	0.7391	 = Validation score   (roc_auc)
# 	253.88s	 = Training   runtime
# 	1.93s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2831.82s of the 4376.86s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.69%)
# 	0.7388	 = Validation score   (roc_auc)
# 	646.31s	 = Training   runtime
# 	1.42s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2183.62s of the 3728.66s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/6.6 GB
# 	0.7284	 = Validation score   (roc_auc)
# 	10.55s	 = Training   runtime
# 	6.92s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2165.67s of the 3710.71s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/5.9 GB
# 	0.7292	 = Validation score   (roc_auc)
# 	12.07s	 = Training   runtime
# 	6.87s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2146.30s of the 3691.34s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=14.74%)
# 	0.7391	 = Validation score   (roc_auc)
# 	2201.61s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 1488.04s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.0/6.0 GB
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.412, 'LightGBMXT_BAG_L1': 0.353, 'LightGBM_BAG_L1': 0.176, 'RandomForestEntr_BAG_L1': 0.059}
# 	0.7396	 = Validation score   (roc_auc)
# 	3.83s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Included models: ['GBM', 'CAT', 'XGB', 'RF', 'XT'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 64 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1484.17s of the 1484.14s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.03%)
# 	0.7389	 = Validation score   (roc_auc)
# 	3.42s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1477.58s of the 1477.55s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.03%)
# 	0.739	 = Validation score   (roc_auc)
# 	49.36s	 = Training   runtime
# 	0.74s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 1426.45s of the 1426.42s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/7.9 GB
# 	0.7499	 = Validation score   (roc_auc)
# 	18.46s	 = Training   runtime
# 	7.36s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 1400.16s of the 1400.13s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/6.7 GB
# 	0.7497	 = Validation score   (roc_auc)
# 	21.8s	 = Training   runtime
# 	7.18s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1370.75s of the 1370.72s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=13.70%)
# 	0.7392	 = Validation score   (roc_auc)
# 	283.6s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 1085.44s of the 1085.42s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/7.6 GB
# 	0.7462	 = Validation score   (roc_auc)
# 	9.2s	 = Training   runtime
# 	6.78s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 1069.01s of the 1068.98s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/7.1 GB
# 	0.7456	 = Validation score   (roc_auc)
# 	9.71s	 = Training   runtime
# 	6.94s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1051.91s of the 1051.89s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.82%)
# 	0.7388	 = Validation score   (roc_auc)
# 	10.65s	 = Training   runtime
# 	1.0s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1038.79s of the 1038.76s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.12%)
# 	0.739	 = Validation score   (roc_auc)
# 	8.2s	 = Training   runtime
# 	1.48s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 1028.27s of the 1028.24s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.24%)
# 	0.7391	 = Validation score   (roc_auc)
# 	36.02s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 990.59s of the 990.56s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.34%)
# 	0.7393	 = Validation score   (roc_auc)
# 	13.08s	 = Training   runtime
# 	3.65s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 975.02s of the 974.99s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=12.01%)
# 	0.739	 = Validation score   (roc_auc)
# 	105.51s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 867.78s of the 867.75s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.96%)
# 	0.739	 = Validation score   (roc_auc)
# 	16.91s	 = Training   runtime
# 	3.77s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 848.23s of the 848.20s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=10.42%)
# 	0.7388	 = Validation score   (roc_auc)
# 	43.05s	 = Training   runtime
# 	2.67s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 803.01s of the 802.98s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/8.0 GB
# 	0.7479	 = Validation score   (roc_auc)
# 	48.63s	 = Training   runtime
# 	7.38s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 746.48s of the 746.46s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=12.08%)
# 	0.7392	 = Validation score   (roc_auc)
# 	217.61s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 526.75s of the 526.72s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=12.24%)
# 	0.7392	 = Validation score   (roc_auc)
# 	958.5s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -434.19s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/6.9 GB
# 	Ensemble Weights: {'RandomForestGini_BAG_L2': 0.375, 'RandomForestEntr_BAG_L2': 0.375, 'ExtraTrees_r42_BAG_L2': 0.25}
# 	0.7518	 = Validation score   (roc_auc)
# 	17.09s	 = Training   runtime
# 	0.03s	 = Validation runtime
# AutoGluon training complete, total runtime = 5086.03s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 4815.0 rows/s (51271 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_final")
#                      model  score_test  score_val eval_metric  pred_time_test  \
# 0  RandomForestEntr_BAG_L1    0.915482   0.729245     roc_auc        1.589970
# 1  RandomForestGini_BAG_L1    0.914643   0.728353     roc_auc        1.541960
# 2    ExtraTreesEntr_BAG_L2    0.803931   0.745550     roc_auc        9.377821
# 3    ExtraTreesGini_BAG_L2    0.803658   0.746231     roc_auc        9.332817
# 4      LightGBM_r96_BAG_L2    0.779919   0.739012     roc_auc       12.831973
#
#    pred_time_val     fit_time  pred_time_test_marginal  \
# 0       6.869208    12.072125                 1.589970
# 1       6.923969    10.554633                 1.541960
# 2      24.230652  3134.141920                 1.499437
# 3      24.069599  3133.628072                 1.454433
# 4      21.063960  3141.334113                 4.953589
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                6.869208          12.072125            1       True
# 1                6.923969          10.554633            1       True
# 2                6.937764           9.713758            2       True
# 3                6.776711           9.199910            2       True
# 4                3.771072          16.905951            2       True
#
#    fit_order
# 0          4
# 1          3
# 2         13
# 3         12
# 4         19

# %%
# # --- 제출 파일 생성 ---
from datetime import datetime
submission = pd.read_csv('../Data/sample_submission.csv')
submission['probability'] = final_probs.values

# 현재 시간 가져오기 (예: 0206_1031)
now = datetime.now().strftime('%m%d_%H%M')
file_name = f"{now}_submission.csv"
submission.to_csv(file_name, index=False)

print(f"학습 및 예측이 완료되었습니다. 결과가 {file_name}에 저장되었습니다.")
# Out:
# 학습 및 예측이 완료되었습니다. 결과가 0208_0147_submission.csv에 저장되었습니다.

# %%
# --- 피처 중요도 ---
fi = predictor.feature_importance(data=train_df.sample(n=min(5000, len(train_df)), random_state=42))
display(fi.head(30))
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['불임 원인 - 여성 요인', '불임 원인 - 정자 면역학적 요인']
# Computing feature importance via permutation shuffling for 67 features using 5000 rows with 5 shuffle sets...
# 	846.7s	= Expected runtime (169.34s per shuffle set)
# 	88.07s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                        importance    stddev       p_value  n  p99_high  \
# 시술 당시 나이                 0.065305  0.002255  1.703696e-07  5  0.069949
# 이식된 배아 수                 0.052677  0.004514  6.405187e-06  5  0.061971
# 배아 이식 경과일                0.042413  0.001841  4.247209e-07  5  0.046203
# 저장된 배아 수                 0.033359  0.002772  5.670270e-06  5  0.039067
# IVF 시술 횟수                0.012512  0.001119  7.595362e-06  5  0.014816
# 총 생성 배아 수                0.012202  0.000642  9.162058e-07  5  0.013523
# 배아_이식_효율                 0.008072  0.002636  1.189874e-03  5  0.013499
# 클리닉 내 총 시술 횟수            0.008045  0.001327  8.581371e-05  5  0.010778
# 총 임신 횟수                  0.006967  0.001144  8.409184e-05  5  0.009322
# 불임 원인 - 남성 요인            0.005435  0.001488  6.117968e-04  5  0.008498
# 총 출산 횟수                  0.004449  0.000302  2.529864e-06  5  0.005071
# 불임 원인 - 난관 질환            0.004352  0.000811  1.382271e-04  5  0.006021
# 나이_대비_이식수                0.003431  0.001161  1.359340e-03  5  0.005822
# 정자 기증자 나이                0.002976  0.000764  4.782574e-04  5  0.004549
# 임신 시도 또는 마지막 임신 경과 연수    0.002240  0.000516  3.149649e-04  5  0.003302
# IVF 임신 횟수                0.001993  0.000405  1.934353e-04  5  0.002826
# 난자 혼합 경과일                0.001973  0.000328  8.828285e-05  5  0.002649
# 정자 출처                    0.001915  0.000783  2.722126e-03  5  0.003529
# 난자 출처                    0.001884  0.000432  3.106689e-04  5  0.002774
# 해동된 배아 수                 0.001877  0.000435  3.238902e-04  5  0.002774
# DI 시술 횟수                 0.001749  0.000480  6.190649e-04  5  0.002738
# 단일 배아 이식 여부              0.001692  0.000769  3.970607e-03  5  0.003276
# 불임 원인 - 자궁내막증            0.001561  0.000634  2.655546e-03  5  0.002866
# 신선 배아 사용 여부              0.001515  0.000500  1.237544e-03  5  0.002544
# 난자 채취 경과일                0.001393  0.000330  3.525338e-04  5  0.002073
# 난자 기증자 나이                0.001373  0.000364  5.381398e-04  5  0.002122
# 배아 생성 주요 이유              0.001155  0.000901  2.276257e-02  5  0.003010
# 착상 전 유전 검사 사용 여부         0.000931  0.000384  2.806379e-03  5  0.001722
# IVF 출산 횟수                0.000725  0.000196  5.838296e-04  5  0.001129
# 부부 부 불임 원인               0.000676  0.000164  3.831279e-04  5  0.001013
#
#                         p99_low
# 시술 당시 나이               0.060662
# 이식된 배아 수               0.043384
# 배아 이식 경과일              0.038623
# 저장된 배아 수               0.027651
# IVF 시술 횟수              0.010208
# 총 생성 배아 수              0.010880
# 배아_이식_효율               0.002645
# 클리닉 내 총 시술 횟수          0.005311
# 총 임신 횟수                0.004612
# 불임 원인 - 남성 요인          0.002371
# 총 출산 횟수                0.003827
# 불임 원인 - 난관 질환          0.002682
# 나이_대비_이식수              0.001040
# 정자 기증자 나이              0.001403
# 임신 시도 또는 마지막 임신 경과 연수  0.001178
# IVF 임신 횟수              0.001160
# 난자 혼합 경과일              0.001298
# 정자 출처                  0.000302
# 난자 출처                  0.000994
# 해동된 배아 수               0.000981
# DI 시술 횟수               0.000760
# 단일 배아 이식 여부            0.000108
# 불임 원인 - 자궁내막증          0.000255
# 신선 배아 사용 여부            0.000486
# 난자 채취 경과일              0.000713
# 난자 기증자 나이              0.000625
# 배아 생성 주요 이유           -0.000699
# 착상 전 유전 검사 사용 여부       0.000140
# IVF 출산 횟수              0.000321
# 부부 부 불임 원인             0.000339

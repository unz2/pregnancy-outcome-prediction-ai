# %%
import pandas as pd
import numpy as np
from autogluon.tabular import TabularPredictor
import warnings
warnings.filterwarnings('ignore')

# 1. 데이터 로드
train_df = pd.read_csv("../Data/train.csv")
test_df = pd.read_csv("../Data/test.csv")

# 2. 전처리 함수 (기존과 동일)
def preprocess(df):
    df_copy = df.copy()
    
    # 시술_대분류
    def major_procedure(x):
        if pd.isna(x):
            return "Unknown"
        if "IUI" in x:
            return "IUI"
        if "DI" in x:
            return "Other"
        if "ICSI" in x:
            return "ICSI"
        if "IVF" in x:
            return "IVF"
        return "Other"
    
    df_copy["시술_대분류"] = df_copy["특정 시술 유형"].apply(major_procedure)
    
    # BLASTOCYST 포함 여부
    df_copy["BLASTOCYST_포함"] = df_copy["특정 시술 유형"].str.contains("BLASTOCYST", na=False).astype(int)
    
    # 배아 이식 여부
    embryo_stage_cols = [
        "단일 배아 이식 여부", "착상 전 유전 진단 사용 여부", "배아 생성 주요 이유",
        "총 생성 배아 수", "미세주입된 난자 수", "미세주입에서 생성된 배아 수",
        "이식된 배아 수", "미세주입 배아 이식 수", "저장된 배아 수",
        "미세주입 후 저장된 배아 수", "해동된 배아 수", "해동 난자 수",
        "수집된 신선 난자 수", "저장된 신선 난자 수", "혼합된 난자 수",
        "파트너 정자와 혼합된 난자 수", "기증자 정자와 혼합된 난자 수",
        "동결 배아 사용 여부", "신선 배아 사용 여부", "기증 배아 사용 여부", "대리모 여부",
    ]
    
    df_copy["배아_이식_미도달"] = df_copy[embryo_stage_cols].isna().all(axis=1).astype(int)
    df_copy["배아_이식_여부"] = 1 - df_copy["배아_이식_미도달"]
    
    # 배아 진행 단계
    def embryo_stage(row):
        if row['배아_이식_여부'] == 0:
            return '배아단계_미도달'
        elif pd.isna(row['총 생성 배아 수']) or row['총 생성 배아 수'] == 0:
            return '배아생성_실패'
        elif pd.isna(row['이식된 배아 수']) or row['이식된 배아 수'] == 0:
            return '이식_미실시'
        else:
            return '이식_완료'
    
    df_copy['배아_진행_단계'] = df_copy.apply(embryo_stage, axis=1)
    
    # 총시술_bin3
    def collapse_trials(x):
        if x == '0회':
            return '0회'
        elif x in ['1회', '2회']:
            return '1–2회'
        else:
            return '3회 이상'
    
    df_copy["총시술_bin3"] = df_copy["총 시술 횟수"].apply(collapse_trials)
    
    # 나이_3구간
    def age_group_simple(age):
        if age == '알 수 없음':
            return 'Unknown'
        elif age == '만18-34세':
            return '34세 이하'
        elif age in ['만35-37세', '만38-39세']:
            return '35-39세'
        else:
            return '40세 이상'
    
    df_copy['나이_3구간'] = df_copy['시술 당시 나이'].apply(age_group_simple)
    
    # 이식배아_구간
    def embryo_count_bin(count):
        if pd.isna(count) or count == 0:
            return '0개'
        elif count <= 2:
            return '1-2개'
        else:
            return '3개 이상'
    
    df_copy['이식배아_구간'] = df_copy['이식된 배아 수'].apply(embryo_count_bin)
    
    # Day5_이식_여부
    df_copy['Day5_이식_여부'] = (df_copy['배아 이식 경과일'] == 5.0).astype(int)
    
    # 불임원인_복잡도
    infertility_cols = [
        "남성 주 불임 원인", "남성 부 불임 원인", "여성 주 불임 원인", "여성 부 불임 원인",
        "부부 주 불임 원인", "부부 부 불임 원인", "불명확 불임 원인",
        "불임 원인 - 난관 질환", "불임 원인 - 남성 요인", "불임 원인 - 배란 장애",
        "불임 원인 - 여성 요인", "불임 원인 - 자궁경부 문제", "불임 원인 - 자궁내막증",
        "불임 원인 - 정자 농도", "불임 원인 - 정자 면역학적 요인", "불임 원인 - 정자 운동성",
        "불임 원인 - 정자 형태"
    ]
    
    df_copy["불임_원인_개수"] = df_copy[infertility_cols].sum(axis=1)
    
    def infertility_complexity(count):
        if count == 0:
            return 'None'
        elif count == 1:
            return 'Single'
        elif count == 2:
            return 'Double'
        else:
            return 'Multiple'
    
    df_copy['불임원인_복잡도'] = df_copy['불임_원인_개수'].apply(infertility_complexity)
    
    # 배아_해동_실시_여부
    df_copy['배아_해동_실시_여부'] = df_copy['배아 해동 경과일'].notna().astype(int)
    
    # 배아 효율 비율 변수들
    df_copy['배아_생성_효율'] = df_copy['총 생성 배아 수'] / (df_copy['수집된 신선 난자 수'] + 1)
    df_copy['배아_이식_비율'] = df_copy['이식된 배아 수'] / (df_copy['총 생성 배아 수'] + 1)
    df_copy['배아_저장_비율'] = df_copy['저장된 배아 수'] / (df_copy['총 생성 배아 수'] + 1)
    
    # 교호작용 변수들
    df_copy['나이×Day5'] = df_copy['시술 당시 나이'].astype(str) + '_' + df_copy['Day5_이식_여부'].astype(str)
    df_copy['시술횟수×나이'] = df_copy['총시술_bin3'] + '_' + df_copy['나이_3구간']

    # 불필요 컬럼 제거
    df_copy = df_copy.drop(['ID', '배아_이식_미도달', '불임 원인 - 자궁경부 문제'], axis=1)
    
    return df_copy

# 3. 전처리 적용
train_df = preprocess(train_df)
test_df = preprocess(test_df)

# ============================
# 5. AutoGluon 학습
# ============================

predictor = TabularPredictor(
    label='임신 성공 여부',
    eval_metric='roc_auc',
    problem_type='binary',
    path='ag_models_out_vhm',
)

predictor.fit(
    train_data=train_df,
    time_limit=10800,
    presets='best_quality',
    num_bag_folds=5,
    num_bag_sets=1,
    num_stack_levels=1,
)

# ==========================================
# 예측 (Test Data 활용) - 최종 결과를 확률로 출력 (Positive 클래스에 대한 확률만 추출)
# ==========================================

pred_probs = predictor.predict_proba(test_df)
final_probs = pred_probs.iloc[:, 1]
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.11.14
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 25.2.0: Tue Nov 18 21:09:40 PST 2025; root:xnu-12377.61.12~1/RELEASE_ARM64_T6000
# CPU Count:          10
# Pytorch Version:    2.9.1
# CUDA Version:       CUDA is not available
# GPU Count:          WARNING: Exception was raised when calculating GPU count (AssertionError)
# Memory Avail:       7.85 GB / 16.00 GB (49.0%)
# Disk Space Avail:   161.41 GB / 460.43 GB (35.1%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 2700s of the 10800s of remaining time (25%).
# DyStack: Disabling memory safe fit mode in DyStack because GPUs were detected and num_gpus='auto' (GPUs cannot be used in memory safe fit mode). If you want to use memory safe fit mode, manually set `num_gpus=0`.
# Running DyStack sub-fit ...
# Beginning AutoGluon training ... Time limit = 2700s
# AutoGluon will save models to "/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_out_vhm/ds_sub_fit/sub_fit_ho"
# Train Data Rows:    227867
# Train Data Columns: 82
# Label Column:       임신 성공 여부
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8450.77 MB
# 	Train Data (Original)  Memory Usage: 615.32 MB (7.3% of available memory)
# 	Warning: Data size prior to feature transformation consumes 7.3% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 25 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 1): ['불임 원인 - 여성 요인']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 2): ['불임 원인 - 정자 운동성', '배아_이식_여부']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('int', []) : 2 | ['불임 원인 - 정자 운동성', '배아_이식_여부']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 32 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 검사 사용 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', ...]
# 		('int', [])    : 19 | ['배란 자극 여부', '남성 주 불임 원인', '남성 부 불임 원인', '여성 주 불임 원인', '여성 부 불임 원인', ...]
# 		('object', []) : 28 | ['시술 시기 코드', '시술 당시 나이', '시술 유형', '특정 시술 유형', '배란 유도 유형', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 27 | ['시술 시기 코드', '시술 당시 나이', '특정 시술 유형', '배란 유도 유형', '배아 생성 주요 이유', ...]
# 		('float', [])     : 28 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', '미세주입된 난자 수', ...]
# 		('int', [])       :  1 | ['불임_원인_개수']
# 		('int', ['bool']) : 23 | ['시술 유형', '배란 자극 여부', '착상 전 유전 검사 사용 여부', '남성 주 불임 원인', '남성 부 불임 원인', ...]
# 	2.1s = Fit runtime
# 	79 features in original data used to generate 79 features in processed data.
# 	Train Data (Processed) Memory Usage: 61.29 MB (0.7% of available memory)
# Data preprocessing and feature engineering runtime = 2.31s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1798.01s of the 2697.68s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.78%)
# 	0.7393	 = Validation score   (roc_auc)
# 	5.28s	 = Training   runtime
# 	1.9s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1788.02s of the 2687.70s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.76%)
# 	0.739	 = Validation score   (roc_auc)
# 	4.47s	 = Training   runtime
# 	1.24s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1781.52s of the 2681.20s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/7.3 GB
# 	0.7291	 = Validation score   (roc_auc)
# 	11.14s	 = Training   runtime
# 	7.06s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1762.82s of the 2662.50s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/6.9 GB
# 	0.7297	 = Validation score   (roc_auc)
# 	11.18s	 = Training   runtime
# 	6.9s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1744.30s of the 2643.98s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=12.46%)
# 	0.7395	 = Validation score   (roc_auc)
# 	723.61s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1018.98s of the 1918.65s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/7.2 GB
# 	0.7311	 = Validation score   (roc_auc)
# 	8.68s	 = Training   runtime
# 	6.7s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1003.18s of the 1902.85s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/7.1 GB
# 	0.7312	 = Validation score   (roc_auc)
# 	9.08s	 = Training   runtime
# 	6.95s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 986.70s of the 1886.38s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.98%)
# 	0.736	 = Validation score   (roc_auc)
# 	163.86s	 = Training   runtime
# 	1.92s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 820.18s of the 1719.86s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.25%)
# 	0.7381	 = Validation score   (roc_auc)
# 	20.59s	 = Training   runtime
# 	1.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 797.07s of the 1696.74s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=4.58%)
# 	0.7366	 = Validation score   (roc_auc)
# 	135.58s	 = Training   runtime
# 	1.81s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 659.47s of the 1559.14s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.91%)
# 	0.7375	 = Validation score   (roc_auc)
# 	9.03s	 = Training   runtime
# 	2.28s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 647.65s of the 1547.33s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.15%)
# 	0.7391	 = Validation score   (roc_auc)
# 	105.93s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 539.95s of the 1439.63s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.24%)
# 	0.7376	 = Validation score   (roc_auc)
# 	168.85s	 = Training   runtime
# 	2.4s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 368.25s of the 1267.93s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.30%)
# 	0.739	 = Validation score   (roc_auc)
# 	17.5s	 = Training   runtime
# 	6.39s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 347.08s of the 1246.76s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.24%)
# 	0.7341	 = Validation score   (roc_auc)
# 	276.14s	 = Training   runtime
# 	2.53s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 68.75s of the 968.43s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=12.31%)
# 	0.7389	 = Validation score   (roc_auc)
# 	54.63s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 11.77s of the 911.44s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.79%)
# 	0.7387	 = Validation score   (roc_auc)
# 	9.45s	 = Training   runtime
# 	4.27s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 899.22s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/6.3 GB
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.3, 'NeuralNetTorch_r79_BAG_L1': 0.2, 'LightGBMXT_BAG_L1': 0.15, 'LightGBM_BAG_L1': 0.15, 'RandomForestEntr_BAG_L1': 0.05, 'NeuralNetFastAI_BAG_L1': 0.05, 'NeuralNetTorch_BAG_L1': 0.05, 'CatBoost_r177_BAG_L1': 0.05}
# 	0.7401	 = Validation score   (roc_auc)
# 	11.72s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting 108 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 887.46s of the 887.40s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.77%)
# 	0.7392	 = Validation score   (roc_auc)
# 	4.26s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 881.27s of the 881.21s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.77%)
# 	0.7395	 = Validation score   (roc_auc)
# 	4.15s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 875.18s of the 875.12s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/7.5 GB
# 	0.7384	 = Validation score   (roc_auc)
# 	34.47s	 = Training   runtime
# 	8.2s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 831.99s of the 831.93s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/6.8 GB
# 	0.7392	 = Validation score   (roc_auc)
# 	42.13s	 = Training   runtime
# 	8.47s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 780.86s of the 780.80s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=14.60%)
# 	0.7396	 = Validation score   (roc_auc)
# 	325.19s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 453.69s of the 453.62s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/7.8 GB
# 	0.742	 = Validation score   (roc_auc)
# 	11.42s	 = Training   runtime
# 	7.65s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 434.05s of the 433.99s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/7.1 GB
# 	0.7416	 = Validation score   (roc_auc)
# 	11.91s	 = Training   runtime
# 	7.82s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 413.76s of the 413.70s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.90%)
# 	0.739	 = Validation score   (roc_auc)
# 	171.49s	 = Training   runtime
# 	1.83s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 239.37s of the 239.30s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.60%)
# 	0.7394	 = Validation score   (roc_auc)
# 	17.09s	 = Training   runtime
# 	0.96s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 219.64s of the 219.58s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.57%)
# 	0.7381	 = Validation score   (roc_auc)
# 	97.86s	 = Training   runtime
# 	1.73s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 119.67s of the 119.61s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.10%)
# 	0.7391	 = Validation score   (roc_auc)
# 	9.14s	 = Training   runtime
# 	1.37s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 108.12s of the 108.06s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=12.19%)
# 	0.7395	 = Validation score   (roc_auc)
# 	48.23s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 58.10s of the 58.04s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.55%)
# 	0.7389	 = Validation score   (roc_auc)
# 	46.52s	 = Training   runtime
# 	2.51s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 9.08s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/7.2 GB
# 	Ensemble Weights: {'ExtraTreesGini_BAG_L2': 0.389, 'ExtraTreesEntr_BAG_L2': 0.278, 'RandomForestEntr_BAG_L2': 0.167, 'RandomForestGini_BAG_L2': 0.111, 'NeuralNetTorch_r79_BAG_L1': 0.056}
# 	0.7434	 = Validation score   (roc_auc)
# 	21.0s	 = Training   runtime
# 	0.03s	 = Validation runtime
# AutoGluon training complete, total runtime = 2712.0s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1183.1 rows/s (45574 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_out_vhm/ds_sub_fit/sub_fit_ho")
# Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                           model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBMXT_BAG_L2       0.742790   0.739248     roc_auc       13.098352      54.937008  1739.250867                 0.181930                0.762261           4.264304            2       True         19
# 1        NeuralNetFastAI_BAG_L2       0.742729   0.738985     roc_auc       14.312839      56.003248  1906.477993                 1.396417                1.828502         171.491430            2       True         26
# 2           WeightedEnsemble_L2       0.742701   0.740115     roc_auc        6.337267      16.642794  1330.472766                 0.004262                0.027840          11.715849            2       True         18
# 3     NeuralNetTorch_r79_BAG_L2       0.742645   0.738888     roc_auc       14.446177      56.683363  1781.508770                 1.529755                2.508617          46.522206            2       True         31
# 4               CatBoost_BAG_L1       0.742639   0.739450     roc_auc        0.209233       0.266712   723.609114                 0.209233                0.266712         723.609114            1       True          5
# 5          CatBoost_r177_BAG_L1       0.742626   0.739062     roc_auc        0.060645       0.171932   105.929018                 0.060645                0.171932         105.929018            1       True         12
# 6         NeuralNetTorch_BAG_L2       0.742621   0.738148     roc_auc       14.296632      55.907407  1832.849459                 1.380210                1.732661          97.862896            2       True         28
# 7          CatBoost_r177_BAG_L2       0.742615   0.739516     roc_auc       12.970114      54.265263  1783.219638                 0.053692                0.090517          48.233075            2       True         30
# 8               CatBoost_BAG_L2       0.742504   0.739565     roc_auc       13.003318      54.339385  2060.177751                 0.086896                0.164639         325.191187            2       True         23
# 9             LightGBMXT_BAG_L1       0.742294   0.739259     roc_auc        0.455998       1.903099     5.280691                 0.455998                1.903099           5.280691            1       True          1
# 10               XGBoost_BAG_L2       0.742222   0.739400     roc_auc       13.558256      55.134029  1752.078839                 0.641834                0.959282          17.092276            2       True         27
# 11              LightGBM_BAG_L2       0.742188   0.739489     roc_auc       13.075599      54.806264  1739.140503                 0.159177                0.631518           4.153940            2       True         20
# 12       NeuralNetFastAI_BAG_L1       0.742176   0.735992     roc_auc        1.975845       1.921378   163.860165                 1.975845                1.921378         163.860165            1       True          8
# 13           CatBoost_r9_BAG_L1       0.741906   0.738854     roc_auc        0.128646       0.303895    54.626838                 0.128646                0.303895          54.626838            1       True         16
# 14         LightGBMLarge_BAG_L2       0.741871   0.739080     roc_auc       13.209492      55.543919  1744.128491                 0.293070                1.369173           9.141928            2       True         29
# 15               XGBoost_BAG_L1       0.741654   0.738058     roc_auc        0.608842       1.061457    20.586102                 0.608842                1.061457          20.586102            1       True          9
# 16              LightGBM_BAG_L1       0.741503   0.739047     roc_auc        0.236934       1.244550     4.467024                 0.236934                1.244550           4.467024            1       True          2
# 17         LightGBM_r131_BAG_L1       0.741486   0.738972     roc_auc        1.009783       6.389456    17.495432                 1.009783                6.389456          17.495432            1       True         14
# 18          LightGBM_r96_BAG_L1       0.741433   0.738702     roc_auc        0.621451       4.273813     9.451059                 0.621451                4.273813           9.451059            1       True         17
# 19         LightGBMLarge_BAG_L1       0.741198   0.737514     roc_auc        0.413954       2.283955     9.028712                 0.413954                2.283955           9.028712            1       True         11
# 20  NeuralNetFastAI_r191_BAG_L1       0.741111   0.734057     roc_auc        2.489461       2.533939   276.140198                 2.489461                2.533939         276.140198            1       True         15
# 21    NeuralNetTorch_r79_BAG_L1       0.740982   0.737609     roc_auc        1.673500       2.400327   168.845530                 1.673500                2.400327         168.845530            1       True         13
# 22        NeuralNetTorch_BAG_L1       0.740775   0.736650     roc_auc        1.276106       1.808257   135.583531                 1.276106                1.808257         135.583531            1       True         10
# 23          WeightedEnsemble_L3       0.740590   0.743447     roc_auc       14.685197      86.346751  1855.918567                 0.001915                0.029281          21.004460            3       True         32
# 24        ExtraTreesEntr_BAG_L2       0.740198   0.741581     roc_auc       13.341887      61.994440  1746.896816                 0.425465                7.819694          11.910253            2       True         25
# 25        ExtraTreesGini_BAG_L2       0.739439   0.741987     roc_auc       13.361011      61.828540  1746.403859                 0.444589                7.653794          11.417295            2       True         24
# 26      RandomForestEntr_BAG_L2       0.738288   0.739209     roc_auc       13.378372      62.640172  1777.118798                 0.461950                8.465425          42.132234            2       True         22
# 27      RandomForestGini_BAG_L2       0.738010   0.738378     roc_auc       13.351278      62.378557  1769.454324                 0.434856                8.203811          34.467761            2       True         21
# 28        ExtraTreesEntr_BAG_L1       0.736691   0.731209     roc_auc        0.444477       6.954318     9.079771                 0.444477                6.954318           9.079771            1       True          7
# 29        ExtraTreesGini_BAG_L1       0.735875   0.731093     roc_auc        0.442169       6.696537     8.679467                 0.442169                6.696537           8.679467            1       True          6
# 30      RandomForestEntr_BAG_L1       0.733703   0.729727     roc_auc        0.444744       6.898699    11.181844                 0.444744                6.898699          11.181844            1       True          4
# 31      RandomForestGini_BAG_L1       0.732853   0.729066     roc_auc        0.424634       7.062422    11.142068                 0.424634                7.062422          11.142068            1       True          3
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	2733s	 = DyStack   runtime |	8067s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 8067s
# AutoGluon will save models to "/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_out_vhm"
# Train Data Rows:    256351
# Train Data Columns: 82
# Label Column:       임신 성공 여부
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8209.98 MB
# 	Train Data (Original)  Memory Usage: 750.01 MB (9.1% of available memory)
# 	Warning: Data size prior to feature transformation consumes 9.1% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 25 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 1): ['불임 원인 - 여성 요인']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 1): ['배아_이식_여부']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('int', []) : 1 | ['배아_이식_여부']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 32 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 검사 사용 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', ...]
# 		('int', [])    : 20 | ['배란 자극 여부', '남성 주 불임 원인', '남성 부 불임 원인', '여성 주 불임 원인', '여성 부 불임 원인', ...]
# 		('object', []) : 28 | ['시술 시기 코드', '시술 당시 나이', '시술 유형', '특정 시술 유형', '배란 유도 유형', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 27 | ['시술 시기 코드', '시술 당시 나이', '특정 시술 유형', '배란 유도 유형', '배아 생성 주요 이유', ...]
# 		('float', [])     : 28 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', '미세주입된 난자 수', ...]
# 		('int', [])       :  1 | ['불임_원인_개수']
# 		('int', ['bool']) : 24 | ['시술 유형', '배란 자극 여부', '착상 전 유전 검사 사용 여부', '남성 주 불임 원인', '남성 부 불임 원인', ...]
# 	2.5s = Fit runtime
# 	80 features in original data used to generate 80 features in processed data.
# 	Train Data (Processed) Memory Usage: 69.20 MB (0.9% of available memory)
# Data preprocessing and feature engineering runtime = 2.84s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 8063.71s of the 8063.70s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.56%)
# 	0.7398	 = Validation score   (roc_auc)
# 	6.17s	 = Training   runtime
# 	1.8s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 8054.96s of the 8054.95s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.88%)
# 	0.7394	 = Validation score   (roc_auc)
# 	5.25s	 = Training   runtime
# 	1.41s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 8047.67s of the 8047.66s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/7.5 GB
# 	0.7307	 = Validation score   (roc_auc)
# 	11.58s	 = Training   runtime
# 	7.54s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 8028.09s of the 8028.09s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/7.0 GB
# 	0.7315	 = Validation score   (roc_auc)
# 	12.34s	 = Training   runtime
# 	7.86s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 8007.44s of the 8007.44s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=12.73%)
# 	0.7399	 = Validation score   (roc_auc)
# 	1089.12s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 6916.49s of the 6916.48s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/7.5 GB
# 	0.7324	 = Validation score   (roc_auc)
# 	10.15s	 = Training   runtime
# 	7.53s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 6898.37s of the 6898.37s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/7.3 GB
# 	0.7326	 = Validation score   (roc_auc)
# 	10.24s	 = Training   runtime
# 	7.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 6880.27s of the 6880.26s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=10.21%)
# 	0.737	 = Validation score   (roc_auc)
# 	117.02s	 = Training   runtime
# 	1.34s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 6760.71s of the 6760.70s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.16%)
# 	0.7389	 = Validation score   (roc_auc)
# 	21.63s	 = Training   runtime
# 	1.33s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 6736.58s of the 6736.58s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=4.91%)
# 	0.7372	 = Validation score   (roc_auc)
# 	126.34s	 = Training   runtime
# 	2.31s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 6607.87s of the 6607.87s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.11%)
# 	0.7382	 = Validation score   (roc_auc)
# 	9.31s	 = Training   runtime
# 	2.52s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 6596.29s of the 6596.28s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.04%)
# 	0.7395	 = Validation score   (roc_auc)
# 	124.9s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 6469.64s of the 6469.63s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=4.95%)
# 	0.7369	 = Validation score   (roc_auc)
# 	194.0s	 = Training   runtime
# 	3.02s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 6272.78s of the 6272.77s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.33%)
# 	0.7394	 = Validation score   (roc_auc)
# 	21.24s	 = Training   runtime
# 	7.21s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 6247.46s of the 6247.46s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.46%)
# 	0.7367	 = Validation score   (roc_auc)
# 	438.33s	 = Training   runtime
# 	3.08s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 5806.82s of the 5806.81s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=13.55%)
# 	0.7399	 = Validation score   (roc_auc)
# 	149.44s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 5655.02s of the 5655.01s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.99%)
# 	0.7401	 = Validation score   (roc_auc)
# 	46.88s	 = Training   runtime
# 	10.46s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 5603.39s of the 5603.38s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.12%)
# 	0.7358	 = Validation score   (roc_auc)
# 	322.79s	 = Training   runtime
# 	2.66s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 5278.39s of the 5278.38s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=10.80%)
# 	0.7372	 = Validation score   (roc_auc)
# 	63.57s	 = Training   runtime
# 	3.31s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 5211.94s of the 5211.94s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/7.8 GB
# 	0.7221	 = Validation score   (roc_auc)
# 	56.83s	 = Training   runtime
# 	8.38s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 5146.18s of the 5146.17s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.13%)
# 	0.7398	 = Validation score   (roc_auc)
# 	1364.54s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 3779.43s of the 3779.43s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.19%)
# 	0.7366	 = Validation score   (roc_auc)
# 	69.67s	 = Training   runtime
# 	0.93s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 3707.20s of the 3707.20s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=14.62%)
# 	0.7397	 = Validation score   (roc_auc)
# 	409.83s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 3294.83s of the 3294.82s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/8.9 GB
# 	Warning: Reducing model 'n_estimators' from 300 -> 292 due to low memory. Expected memory usage reduced from 15.4% -> 15.0% of available memory...
# 	0.7045	 = Validation score   (roc_auc)
# 	83.71s	 = Training   runtime
# 	9.84s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 3200.37s of the 3200.36s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.10%)
# 	0.7391	 = Validation score   (roc_auc)
# 	10.9s	 = Training   runtime
# 	2.99s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 3186.44s of the 3186.44s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.18%)
# 	0.7354	 = Validation score   (roc_auc)
# 	449.16s	 = Training   runtime
# 	4.3s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 2734.71s of the 2734.70s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.77%)
# 	0.7394	 = Validation score   (roc_auc)
# 	40.48s	 = Training   runtime
# 	1.54s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 2691.51s of the 2691.50s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=4.42%)
# 	0.7363	 = Validation score   (roc_auc)
# 	754.99s	 = Training   runtime
# 	3.38s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 1934.13s of the 1934.13s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.89%)
# 	0.7391	 = Validation score   (roc_auc)
# 	7.75s	 = Training   runtime
# 	1.87s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 1924.09s of the 1924.08s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=4.34%)
# 	0.7377	 = Validation score   (roc_auc)
# 	945.25s	 = Training   runtime
# 	2.52s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 976.63s of the 976.63s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.49%)
# 	0.7394	 = Validation score   (roc_auc)
# 	147.8s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 826.88s of the 826.87s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.36%)
# 	0.7257	 = Validation score   (roc_auc)
# 	391.32s	 = Training   runtime
# 	5.05s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 432.71s of the 432.71s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.09%)
# 	0.7388	 = Validation score   (roc_auc)
# 	9.9s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 420.33s of the 420.33s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/9.3 GB
# 	0.7239	 = Validation score   (roc_auc)
# 	71.69s	 = Training   runtime
# 	8.36s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 339.84s of the 339.83s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.11%)
# 	0.7396	 = Validation score   (roc_auc)
# 	271.23s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 66.77s of the 66.77s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.11%)
# 	0.7334	 = Validation score   (roc_auc)
# 	51.27s	 = Training   runtime
# 	2.91s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 12.95s of the 12.94s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.72%)
# 	0.7351	 = Validation score   (roc_auc)
# 	9.98s	 = Training   runtime
# 	2.51s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 806.37s of the -0.29s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/7.6 GB
# 	Ensemble Weights: {'CatBoost_r9_BAG_L1': 0.16, 'CatBoost_BAG_L1': 0.08, 'NeuralNetFastAI_BAG_L1': 0.08, 'LightGBM_r96_BAG_L1': 0.08, 'NeuralNetTorch_r22_BAG_L1': 0.08, 'CatBoost_r137_BAG_L1': 0.08, 'XGBoost_r89_BAG_L1': 0.08, 'NeuralNetTorch_r86_BAG_L1': 0.08, 'RandomForestEntr_BAG_L1': 0.04, 'NeuralNetTorch_r79_BAG_L1': 0.04, 'NeuralNetFastAI_r191_BAG_L1': 0.04, 'NeuralNetFastAI_r102_BAG_L1': 0.04, 'LightGBM_r188_BAG_L1': 0.04, 'NeuralNetTorch_r30_BAG_L1': 0.04, 'LightGBM_r130_BAG_L1': 0.04}
# 	0.7408	 = Validation score   (roc_auc)
# 	33.16s	 = Training   runtime
# 	0.04s	 = Validation runtime
# AutoGluon training complete, total runtime = 8100.11s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 1402.6 rows/s (51271 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_out_vhm")

# %%
# --- 리더보드 출력 ---
lb = predictor.leaderboard(train_df, silent=True)
display(lb.head())
# Out:
#                       model  score_test  score_val eval_metric  \
# 0  RandomForest_r195_BAG_L1    0.998947   0.704465     roc_auc
# 1     ExtraTrees_r42_BAG_L1    0.958652   0.722053     roc_auc
# 2   RandomForestEntr_BAG_L1    0.929323   0.731481     roc_auc
# 3    ExtraTrees_r172_BAG_L1    0.928182   0.723917     roc_auc
# 4   RandomForestGini_BAG_L1    0.927689   0.730747     roc_auc
#
#    pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0        3.918013       9.839082  83.714784                 3.918013
# 1        2.316210       8.380874  56.828550                 2.316210
# 2        1.989370       7.860657  12.336424                 1.989370
# 3        2.102410       8.356351  71.685420                 2.102410
# 4        1.956134       7.535022  11.578210                 1.956134
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                9.839082          83.714784            1       True
# 1                8.380874          56.828550            1       True
# 2                7.860657          12.336424            1       True
# 3                8.356351          71.685420            1       True
# 4                7.535022          11.578210            1       True
#
#    fit_order
# 0         24
# 1         20
# 2          4
# 3         34
# 4          3

# %%
# --- 제출 파일 생성 ---
from datetime import datetime
submission = pd.read_csv('../Data/sample_submission.csv')
submission['probability'] = final_probs.values

# 현재 시간 가져오기 (예: 0206_1031)
now = datetime.now().strftime('%m%d_%H%M')
file_name = f"AG_{now}_submission.csv"
submission.to_csv(file_name, index=False)

print(f"학습 및 예측이 완료되었습니다. 결과가 {file_name}에 저장되었습니다.")
# Out:
# 학습 및 예측이 완료되었습니다. 결과가 AG_0210_1848_submission.csv에 저장되었습니다.

# %%
# --- 피처 중요도 ---
fi = predictor.feature_importance(data=train_df.sample(n=min(5000, len(train_df)), random_state=42))
fi.to_excel('fihm.xlsx')
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['불임 원인 - 여성 요인', '배아_이식_여부']
# Computing feature importance via permutation shuffling for 80 features using 5000 rows with 5 shuffle sets...
# 	1323.23s	= Expected runtime (264.65s per shuffle set)
# 	793.97s	= Actual runtime (Completed 5 of 5 shuffle sets)

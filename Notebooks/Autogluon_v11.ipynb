# %%
import random
import os
import numpy as np
import pandas as pd
from datetime import datetime
from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

random.seed(42)
os.environ['PYTHONHASHSEED'] = str(42)
np.random.seed(42)

# ==========================================
# 1. 데이터 로드
# ==========================================

train_df = pd.read_csv('../Data/train.csv')
test_df = pd.read_csv('../Data/test.csv')
target = '임신 성공 여부'

# ==========================================
# 2. 파생변수 생성
# ==========================================

def derive_features(df):
    # 0. 원본 데이터 유지를 위해 복사본 생성 (선택 사항)
    df = df.copy()

    # 1. 수치형 변환 및 클리닝 (정규표현식 활용)
    count_cols = [
        '총 시술 횟수', '클리닉 내 총 시술 횟수', '총 임신 횟수', '총 출산 횟수',
        'IVF 시술 횟수', 'DI 시술 횟수', 'IVF 임신 횟수', 'DI 임신 횟수',
        'IVF 출산 횟수', 'DI 출산 횟수', '총 생성 배아 수', '이식된 배아 수', 
        '미세주입된 난자 수', '미세주입에서 생성된 배아 수', '저장된 배아 수'
    ]
    
    for col in count_cols:
        if df[col].dtype == 'object':
            # '회', ' 이상' 등을 제거하고 공백 정리 후 숫자형으로 변환
            df[col] = df[col].astype(str).str.replace(r'회| 이상', '', regex=True).str.strip()
            df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

    target_cols = [
            '총 생성 배아 수', '기증자 정자와 혼합된 난자 수', '파트너 정자와 혼합된 난자 수',
            '미세주입된 난자 수', '혼합된 난자 수', '저장된 신선 난자 수', '해동 난자 수',
            '해동된 배아 수', '미세주입 후 저장된 배아 수', '저장된 배아 수',
            '미세주입 배아 이식 수', '이식된 배아 수', '미세주입에서 생성된 배아 수',
            '수집된 신선 난자 수', '단일 배아 이식 여부', '착상 전 유전 진단 사용 여부', '대리모 여부',
            '기증 배아 사용 여부', '신선 배아 사용 여부', '동결 배아 사용 여부'
        ]

    # 시술 유형이 DI인 행에 대해서만 지정된 컬럼들의 NaN을 0으로 채움
    df.loc[df['특정 시술 유형'] == 'DI', target_cols] = df.loc[df['특정 시술 유형'] == 'DI', target_cols].fillna(0)


    # 2. 연령 관련 변수 생성
    age_order = {
        '만18-34세': 1, '만35-37세': 2, '만38-39세': 3, 
        '만40-42세': 4, '만43-44세': 5, '만45-50세': 6, '알 수 없음': 7
    }
    df['시술 당시 나이'] = df['시술 당시 나이'].map(age_order).fillna(7)
    
    # 파생 변수 계산 (Zero Division 방지를 위해 1e-6 활용)
    epsilon = 1e-6
    df['나이x배아'] = df['시술 당시 나이'] * df['이식된 배아 수']
    df['연령별 배아 효율'] = df['이식된 배아 수'] / (df['시술 당시 나이'] + epsilon)
    df['배아 발달 기간'] = df['배아 이식 경과일'] - df['난자 혼합 경과일']
    df['이식 비중'] = df['이식된 배아 수'] / (df['이식된 배아 수'] + df['저장된 배아 수'] + epsilon)

    # 3. 난자 및 배아 효율성 변수
    oocyte_cols = ['수집된 신선 난자 수', '혼합된 난자 수', '기증자 정자와 혼합된 난자 수', '해동 난자 수']
    df['총 난자 수'] = df[oocyte_cols].fillna(0).sum(axis=1)
    
    # 0으로 나누기 방지를 위해 총 난자 수가 0인 경우 0으로 처리하거나 epsilon 추가
    df['배아 손실률'] = (df['총 난자 수'] - df['총 생성 배아 수']) / (df['총 난자 수'] + epsilon)
    df['배아 생성 효율'] = df['저장된 배아 수'] / (df['저장된 신선 난자 수'] + epsilon)
    df['수정 효율'] = df['총 생성 배아 수'] / (df['혼합된 난자 수'] + epsilon)
    df['선별 효율'] = df['저장된 배아 수'] / (df['총 생성 배아 수'] + epsilon)

    # 4. 시술 유형 분류 (Vectorized 방식 권장)
    def clean_treatment(val):
        val = str(val).upper()
        if 'ICSI' in val: return 'ICSI'
        if 'IVF' in val: return 'IVF'
        if 'IUI' in val: return 'IUI'
        return 'Other'

    df['특정 시술 유형'] = df['특정 시술 유형'].apply(clean_treatment)

    # 5. 불임 원인 점수 계산
    female_cols = [
        '불임 원인 - 여성 요인', '불임 원인 - 난관 질환', '불임 원인 - 배란 장애', 
        '불임 원인 - 자궁경부 문제', '불임 원인 - 자궁내막증', '여성 주 불임 원인', 
        '여성 부 불임 원인', '부부 주 불임 원인', '부부 부 불임 원인'
    ]
    male_cols = [
        '불임 원인 - 남성 요인', '불임 원인 - 정자 농도', '불임 원인 - 정자 운동성', 
        '불임 원인 - 정자 형태', '불임 원인 - 정자 면역학적 요인', '남성 주 불임 원인', 
        '남성 부 불임 원인', '부부 주 불임 원인', '부부 부 불임 원인'
    ]
    
    df['여성_결함_점수'] = df[female_cols].sum(axis=1)
    df['남성_결함_점수'] = df[male_cols].sum(axis=1)

    # 6. 배아 생성 주요 이유 단순화
    def clean_reason(x):
        if pd.isna(x): return 'Unknown'
        x = str(x)
        if '시술용' in x: return 'Treatment'
        if '기증' in x: return 'Donation'
        if '저장' in x: return 'Storage'
        return 'Other'
    
    df['배아 생성 주요 이유'] = df['배아 생성 주요 이유'].apply(clean_reason)
    
    # 7. 불필요한 컬럼 삭제
    drop_cols = ['시술 시기 코드']
    df.drop(columns=drop_cols + female_cols + male_cols, errors='ignore', inplace=True)
    
    return df

train_df = derive_features(train_df)
test_df = derive_features(test_df)

# 학습용 데이터 내에서 정답이 있는 '자체 테스트셋' 분리
train_data, val_data = train_test_split(train_df, test_size=0.2, random_state=42)

# ==========================================
# 3. 모델 학습 설정
# ==========================================

predictor = TabularPredictor(
    label=target, 
    eval_metric='roc_auc',
    path='ag_models_out_v2',
).fit(
    train_data=train_data,
    time_limit=7200,
    presets='best_quality',
    included_model_types=['GBM', 'CAT', 'XGB', 'NN_TORCH'],
    num_stack_levels=1,
    num_bag_folds=5,
    refit_full=True
)

# ==========================================
# 4. 예측 (Test Data 활용) - 최종 결과를 확률로 출력 (Positive 클래스에 대한 확률만 추출)
# ==========================================

pred_probs = predictor.predict_proba(test_df)
final_probs = pred_probs.iloc[:, 1]

# ==========================================
# 5. 리더보드 출력
# ==========================================

lb = predictor.leaderboard(val_data, silent=True)
display(lb.head())
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="ag_models_out_v2"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.11.14
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 25.2.0: Tue Nov 18 21:09:40 PST 2025; root:xnu-12377.61.12~1/RELEASE_ARM64_T6000
# CPU Count:          10
# Pytorch Version:    2.9.1
# CUDA Version:       CUDA is not available
# GPU Count:          WARNING: Exception was raised when calculating GPU count (AssertionError)
# Memory Avail:       8.09 GB / 16.00 GB (50.5%)
# Disk Space Avail:   167.41 GB / 460.43 GB (36.4%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 1800s of the 7200s of remaining time (25%).
# DyStack: Disabling memory safe fit mode in DyStack because GPUs were detected and num_gpus='auto' (GPUs cannot be used in memory safe fit mode). If you want to use memory safe fit mode, manually set `num_gpus=0`.
# Running DyStack sub-fit ...
# Beginning AutoGluon training ... Time limit = 1800s
# AutoGluon will save models to "/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_out_v2/ds_sub_fit/sub_fit_ho"
# Train Data Rows:    182293
# Train Data Columns: 62
# Label Column:       임신 성공 여부
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8318.80 MB
# 	Train Data (Original)  Memory Usage: 200.59 MB (2.4% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 7 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['ID']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['ID']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 38 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 검사 사용 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', ...]
# 		('int', [])    : 15 | ['시술 당시 나이', '배란 자극 여부', '불명확 불임 원인', '총 시술 횟수', '클리닉 내 총 시술 횟수', ...]
# 		('object', []) :  8 | ['시술 유형', '특정 시술 유형', '배란 유도 유형', '배아 생성 주요 이유', '난자 출처', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  :  7 | ['특정 시술 유형', '배란 유도 유형', '배아 생성 주요 이유', '난자 출처', '정자 출처', ...]
# 		('float', [])     : 34 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', '미세주입된 난자 수', ...]
# 		('int', [])       : 13 | ['시술 당시 나이', '총 시술 횟수', '클리닉 내 총 시술 횟수', 'IVF 시술 횟수', 'DI 시술 횟수', ...]
# 		('int', ['bool']) :  7 | ['시술 유형', '배란 자극 여부', '착상 전 유전 검사 사용 여부', '불명확 불임 원인', 'PGD 시술 여부', ...]
# 	0.9s = Fit runtime
# 	61 features in original data used to generate 61 features in processed data.
# 	Train Data (Processed) Memory Usage: 67.80 MB (0.8% of available memory)
# Data preprocessing and feature engineering runtime = 0.99s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Included models: ['GBM', 'CAT', 'XGB', 'NN_TORCH'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 67 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1199.04s of the 1799.00s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.91%)
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# 	0.7388	 = Validation score   (roc_auc)
# 	3.6s	 = Training   runtime
# 	0.97s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1191.04s of the 1791.00s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.49%)
# 	0.7381	 = Validation score   (roc_auc)
# 	3.14s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1186.08s of the 1786.05s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=12.10%)
# [2026-02-09 14:01:59,692 E 7122 566316] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# 	0.739	 = Validation score   (roc_auc)
# 	157.58s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1026.86s of the 1626.82s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.21%)
# 	0.7379	 = Validation score   (roc_auc)
# 	5.3s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1019.72s of the 1619.69s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.56%)
# 	0.7356	 = Validation score   (roc_auc)
# 	70.68s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 947.14s of the 1547.10s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.29%)
# 	0.737	 = Validation score   (roc_auc)
# 	7.39s	 = Training   runtime
# 	1.56s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 937.23s of the 1537.19s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.89%)
# 	0.7388	 = Validation score   (roc_auc)
# 	18.31s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 917.22s of the 1517.18s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.37%)
# 	0.7355	 = Validation score   (roc_auc)
# 	131.73s	 = Training   runtime
# 	1.43s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 783.56s of the 1383.52s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.39%)
# 	0.7381	 = Validation score   (roc_auc)
# 	13.46s	 = Training   runtime
# 	4.1s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 767.21s of the 1367.18s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.96%)
# 	0.7387	 = Validation score   (roc_auc)
# 	67.26s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 698.27s of the 1298.23s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.83%)
# 	0.7392	 = Validation score   (roc_auc)
# 	20.95s	 = Training   runtime
# 	5.3s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 674.46s of the 1274.43s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.23%)
# 	0.7346	 = Validation score   (roc_auc)
# 	181.97s	 = Training   runtime
# 	1.63s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 490.63s of the 1090.59s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.75%)
# 	0.7354	 = Validation score   (roc_auc)
# 	17.73s	 = Training   runtime
# 	2.0s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 470.85s of the 1070.81s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=10.99%)
# 	0.7389	 = Validation score   (roc_auc)
# 	195.49s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 273.53s of the 873.49s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.73%)
# 	0.7388	 = Validation score   (roc_auc)
# 	54.22s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 217.66s of the 817.63s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.04%)
# 	0.7378	 = Validation score   (roc_auc)
# 	7.54s	 = Training   runtime
# 	1.88s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 208.11s of the 808.07s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.83%)
# 	0.7383	 = Validation score   (roc_auc)
# 	6.69s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 199.68s of the 799.65s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.34%)
# 	0.7354	 = Validation score   (roc_auc)
# 	159.0s	 = Training   runtime
# 	1.8s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 38.75s of the 638.72s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.77%)
# 	0.7377	 = Validation score   (roc_auc)
# 	4.67s	 = Training   runtime
# 	1.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 32.13s of the 632.09s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=4.98%)
# 	0.7324	 = Validation score   (roc_auc)
# 	25.4s	 = Training   runtime
# 	1.39s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 4.81s of the 604.78s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=10.99%)
# 	0.7329	 = Validation score   (roc_auc)
# 	3.65s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 599.38s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/7.3 GB
# 	Ensemble Weights: {'LightGBM_r96_BAG_L1': 0.333, 'CatBoost_BAG_L1': 0.167, 'CatBoost_r137_BAG_L1': 0.125, 'NeuralNetTorch_BAG_L1': 0.083, 'NeuralNetTorch_r30_BAG_L1': 0.083, 'LightGBM_r130_BAG_L1': 0.083, 'CatBoost_r177_BAG_L1': 0.042, 'CatBoost_r9_BAG_L1': 0.042, 'XGBoost_r33_BAG_L1': 0.042}
# 	0.7395	 = Validation score   (roc_auc)
# 	11.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Included models: ['GBM', 'CAT', 'XGB', 'NN_TORCH'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 67 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 588.34s of the 588.28s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.86%)
# 	0.7387	 = Validation score   (roc_auc)
# 	3.44s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 582.94s of the 582.88s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.45%)
# 	0.7384	 = Validation score   (roc_auc)
# 	3.11s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 577.92s of the 577.85s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.87%)
# 	0.7389	 = Validation score   (roc_auc)
# 	61.52s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 514.56s of the 514.50s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.78%)
# 	0.7383	 = Validation score   (roc_auc)
# 	5.62s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 506.99s of the 506.92s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.23%)
# 	0.7378	 = Validation score   (roc_auc)
# 	58.61s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 446.32s of the 446.26s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.52%)
# 	0.7372	 = Validation score   (roc_auc)
# 	7.89s	 = Training   runtime
# 	1.06s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 435.87s of the 435.81s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=12.60%)
# 	0.7388	 = Validation score   (roc_auc)
# 	10.94s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 423.10s of the 423.04s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.29%)
# 	0.7386	 = Validation score   (roc_auc)
# 	97.23s	 = Training   runtime
# 	1.49s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 323.79s of the 323.73s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.65%)
# 	0.7384	 = Validation score   (roc_auc)
# 	12.24s	 = Training   runtime
# 	2.57s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 308.61s of the 308.55s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=13.60%)
# 	0.7386	 = Validation score   (roc_auc)
# 	41.74s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 265.10s of the 265.04s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.92%)
# 	0.7389	 = Validation score   (roc_auc)
# 	10.35s	 = Training   runtime
# 	1.76s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 252.63s of the 252.57s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.39%)
# 	0.7373	 = Validation score   (roc_auc)
# 	115.49s	 = Training   runtime
# 	1.63s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 135.07s of the 135.01s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=12.52%)
# 	0.7371	 = Validation score   (roc_auc)
# 	24.5s	 = Training   runtime
# 	1.44s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 107.82s of the 107.76s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=12.18%)
# 	0.739	 = Validation score   (roc_auc)
# 	40.12s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 65.49s of the 65.43s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=13.34%)
# 	0.7389	 = Validation score   (roc_auc)
# 	41.1s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L2 ... Training model for up to 22.59s of the 22.53s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.34%)
# 	0.7381	 = Validation score   (roc_auc)
# 	7.67s	 = Training   runtime
# 	1.42s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L2 ... Training model for up to 12.78s of the 12.72s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.43%)
# 	0.7388	 = Validation score   (roc_auc)
# 	5.79s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 4.94s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/7.5 GB
# 	Ensemble Weights: {'LightGBM_r96_BAG_L1': 0.273, 'CatBoost_BAG_L1': 0.182, 'CatBoost_r137_BAG_L1': 0.091, 'NeuralNetTorch_r30_BAG_L1': 0.091, 'LightGBM_r130_BAG_L1': 0.091, 'XGBoost_r33_BAG_L2': 0.091, 'NeuralNetTorch_BAG_L1': 0.045, 'CatBoost_r177_BAG_L1': 0.045, 'CatBoost_r9_BAG_L1': 0.045, 'XGBoost_r89_BAG_L2': 0.045}
# 	0.7395	 = Validation score   (roc_auc)
# 	19.53s	 = Training   runtime
# 	0.02s	 = Validation runtime
# AutoGluon training complete, total runtime = 1814.67s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1274.2 rows/s (36459 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/7.8 GB
# 	2.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/7.7 GB
# 	1.71s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	28.05s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.2s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/7.4 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	19.96s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/7.4 GB
# 	5.07s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	4.21s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/7.3 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	43.39s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/7.0 GB
# 	8.12s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	17.38s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/6.8 GB
# 	8.98s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/6.8 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	83.62s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	3.36s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	34.97s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	14.07s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/7.0 GB
# 	5.35s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/6.9 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	171.52s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/6.4 GB
# 	2.98s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/6.5 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	25.31s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r50_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.2s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBM_r96_BAG_L1': 0.333, 'CatBoost_BAG_L1': 0.167, 'CatBoost_r137_BAG_L1': 0.125, 'NeuralNetTorch_BAG_L1': 0.083, 'NeuralNetTorch_r30_BAG_L1': 0.083, 'LightGBM_r130_BAG_L1': 0.083, 'CatBoost_r177_BAG_L1': 0.042, 'CatBoost_r9_BAG_L1': 0.042, 'XGBoost_r33_BAG_L1': 0.042}
# 	11.0s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/6.8 GB
# 	1.74s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/6.7 GB
# 	1.66s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	7.71s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.44s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/6.6 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	14.16s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/6.6 GB
# 	5.49s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	2.24s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/6.7 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	33.03s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/6.1 GB
# 	7.35s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=1.0/6.1 GB
# 	10.11s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/6.1 GB
# 	4.21s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/6.1 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	24.42s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	4.37s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	8.57s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=1.0/6.2 GB
# 	9.49s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/6.1 GB
# 	5.14s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.4s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBM_r96_BAG_L1': 0.273, 'CatBoost_BAG_L1': 0.182, 'CatBoost_r137_BAG_L1': 0.091, 'NeuralNetTorch_r30_BAG_L1': 0.091, 'LightGBM_r130_BAG_L1': 0.091, 'XGBoost_r33_BAG_L2': 0.091, 'NeuralNetTorch_BAG_L1': 0.045, 'CatBoost_r177_BAG_L1': 0.045, 'CatBoost_r9_BAG_L1': 0.045, 'XGBoost_r89_BAG_L2': 0.045}
# 	19.53s	 = Training   runtime
# Refit complete, total runtime = 632.02s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_out_v2/ds_sub_fit/sub_fit_ho")
# Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                              model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBM_r131_BAG_L2       0.736167   0.738434     roc_auc        9.217526      29.203846  1168.000264                 0.464511                2.566961          12.244217            2       True         31
# 1               CatBoost_r9_BAG_L2       0.736051   0.738626     roc_auc        8.833966      26.776163  1197.495077                 0.080951                0.139278          41.739030            2       True         32
# 2             LightGBMLarge_BAG_L2       0.736005   0.737217     roc_auc        8.976529      27.697721  1163.642649                 0.223514                1.060836           7.886602            2       True         28
# 3             CatBoost_BAG_L2_FULL       0.735980        NaN     roc_auc        1.787740            NaN   491.599349                 0.009377                     NaN           7.706149            2       True         65
# 4                   XGBoost_BAG_L2       0.735962   0.738326     roc_auc        9.126872      27.203425  1161.373912                 0.373857                0.566540           5.617865            2       True         26
# 5                  CatBoost_BAG_L2       0.735926   0.738889     roc_auc        8.787905      26.707355  1217.279126                 0.034890                0.070470          61.523079            2       True         25
# 6                  LightGBM_BAG_L2       0.735921   0.738350     roc_auc        8.867650      27.115695  1158.868274                 0.114635                0.478810           3.112227            2       True         24
# 7               XGBoost_r89_BAG_L2       0.735908   0.738843     roc_auc        9.127886      27.171286  1161.550835                 0.374871                0.534401           5.794788            2       True         39
# 8              LightGBM_r96_BAG_L2       0.735873   0.738946     roc_auc        9.058170      28.398139  1166.106824                 0.305155                1.761255          10.350777            2       True         33
# 9             CatBoost_r177_BAG_L2       0.735840   0.738778     roc_auc        8.783549      26.688334  1166.695656                 0.030534                0.051449          10.939609            2       True         29
# 10             CatBoost_r13_BAG_L2       0.735830   0.738935     roc_auc        8.796183      26.711725  1196.851447                 0.043168                0.074840          41.095400            2       True         37
# 11        WeightedEnsemble_L3_FULL       0.735819        NaN     roc_auc        1.930540            NaN   509.201544                 0.002178                     NaN          19.531465            3       True         80
# 12            CatBoost_r137_BAG_L2       0.735812   0.738965     roc_auc        8.782351      26.685305  1195.879839                 0.029336                0.048420          40.123792            2       True         36
# 13        LightGBM_r96_BAG_L2_FULL       0.735804        NaN     roc_auc        1.836683            NaN   488.108099                 0.058320                     NaN           4.214899            2       True         73
# 14               LightGBMXT_BAG_L1       0.735779   0.738783     roc_auc        0.200346       0.966010     3.598994                 0.200346                0.966010           3.598994            1       True          1
# 15               LightGBMXT_BAG_L2       0.735776   0.738733     roc_auc        8.884039      27.194488  1159.197626                 0.131024                0.557603           3.441579            2       True         23
# 16             WeightedEnsemble_L3       0.735775   0.739512     roc_auc        9.693733      28.629749  1205.578210                 0.002264                0.021684          19.531465            3       True         40
# 17        WeightedEnsemble_L2_FULL       0.735746        NaN     roc_auc        0.819227            NaN   302.401486                 0.001806                     NaN          10.998771            2       True         62
# 18             WeightedEnsemble_L2       0.735712   0.739486     roc_auc        3.642407      11.762236   722.679758                 0.003028                0.021136          10.998771            2       True         22
# 19       NeuralNetTorch_r79_BAG_L2       0.735708   0.738563     roc_auc        9.700989      28.131802  1252.981141                 0.947974                1.494917          97.225094            2       True         30
# 20       CatBoost_r137_BAG_L2_FULL       0.735701        NaN     roc_auc        1.788836            NaN   492.463550                 0.010473                     NaN           8.570350            2       True         76
# 21         XGBoost_r89_BAG_L2_FULL       0.735658        NaN     roc_auc        1.839063            NaN   485.295763                 0.060700                     NaN           1.402562            2       True         79
# 22       CatBoost_r177_BAG_L2_FULL       0.735653        NaN     roc_auc        1.788506            NaN   486.130336                 0.010142                     NaN           2.237135            2       True         69
# 23                 CatBoost_BAG_L1       0.735606   0.739017     roc_auc        0.045438       0.082020   157.584172                 0.045438                0.082020         157.584172            1       True          3
# 24             LightGBM_r96_BAG_L1       0.735605   0.739160     roc_auc        0.932958       5.297403    20.951682                 0.932958                5.297403          20.951682            1       True         11
# 25         CatBoost_r9_BAG_L2_FULL       0.735594        NaN     roc_auc        1.799333            NaN   494.006040                 0.020970                     NaN          10.112840            2       True         72
# 26             XGBoost_BAG_L2_FULL       0.735586        NaN     roc_auc        1.838491            NaN   485.330452                 0.060128                     NaN           1.437252            2       True         66
# 27        CatBoost_r13_BAG_L2_FULL       0.735580        NaN     roc_auc        1.789994            NaN   493.381814                 0.011631                     NaN           9.488614            2       True         77
# 28              XGBoost_r89_BAG_L1       0.735574   0.738281     roc_auc        0.358438       0.568397     6.688303                 0.358438                0.568397           6.688303            1       True         17
# 29          LightGBMXT_BAG_L1_FULL       0.735565        NaN     roc_auc        0.043208            NaN     2.126515                 0.043208                     NaN           2.126515            1       True         41
# 30            CatBoost_BAG_L1_FULL       0.735560        NaN     roc_auc        0.009507            NaN    28.053395                 0.009507                     NaN          28.053395            1       True         43
# 31              CatBoost_r9_BAG_L1       0.735559   0.738686     roc_auc        0.126474       0.203417    67.259246                 0.126474                0.203417          67.259246            1       True         10
# 32       CatBoost_r137_BAG_L1_FULL       0.735521        NaN     roc_auc        0.011058            NaN    34.965522                 0.011058                     NaN          34.965522            1       True         54
# 33        LightGBM_r96_BAG_L1_FULL       0.735513        NaN     roc_auc        0.185679            NaN     8.980110                 0.185679                     NaN           8.980110            1       True         51
# 34         CatBoost_r9_BAG_L1_FULL       0.735450        NaN     roc_auc        0.028805            NaN    17.381867                 0.028805                     NaN          17.381867            1       True         50
# 35            LightGBM_r130_BAG_L1       0.735432   0.737689     roc_auc        0.206819       1.048092     4.672266                 0.206819                1.048092           4.672266            1       True         19
# 36            LightGBM_r188_BAG_L1       0.735401   0.737782     roc_auc        0.346678       1.884126     7.542349                 0.346678                1.884126           7.542349            1       True         16
# 37            LightGBM_BAG_L2_FULL       0.735385        NaN     roc_auc        1.803636            NaN   485.550011                 0.025273                     NaN           1.656811            2       True         64
# 38       LightGBM_r130_BAG_L1_FULL       0.735374        NaN     roc_auc        0.046618            NaN     2.975600                 0.046618                     NaN           2.975600            1       True         59
# 39            LightGBM_r188_BAG_L2       0.735373   0.738094     roc_auc        9.037004      28.058076  1163.428076                 0.283989                1.421191           7.672029            2       True         38
# 40       NeuralNetTorch_r22_BAG_L2       0.735313   0.737266     roc_auc        9.651671      28.271370  1271.241761                 0.898656                1.634485         115.485714            2       True         34
# 41            LightGBM_r131_BAG_L1       0.735311   0.738148     roc_auc        0.701452       4.095147    13.460497                 0.701452                4.095147          13.460497            1       True          9
# 42            CatBoost_r137_BAG_L1       0.735285   0.738855     roc_auc        0.053561       0.082623   195.488027                 0.053561                0.082623         195.488027            1       True         14
# 43          LightGBMXT_BAG_L2_FULL       0.735271        NaN     roc_auc        1.806511            NaN   485.629357                 0.028148                     NaN           1.736156            2       True         63
# 44       LightGBM_r188_BAG_L1_FULL       0.735254        NaN     roc_auc        0.066100            NaN     5.353648                 0.066100                     NaN           5.353648            1       True         56
# 45       CatBoost_r177_BAG_L1_FULL       0.735252        NaN     roc_auc        0.008151            NaN     4.208433                 0.008151                     NaN           4.208433            1       True         47
# 46      NeuralNetTorch_BAG_L2_FULL       0.735207        NaN     roc_auc        1.919496            NaN   498.056748                 0.141132                     NaN          14.163548            2       True         67
# 47           NeuralNetTorch_BAG_L2       0.735206   0.737838     roc_auc        9.596254      27.769872  1214.368230                 0.843239                1.132987          58.612183            2       True         27
# 48            LightGBM_BAG_L1_FULL       0.735199        NaN     roc_auc        0.034450            NaN     1.712667                 0.034450                     NaN           1.712667            1       True         42
# 49  NeuralNetTorch_r79_BAG_L2_FULL       0.735134        NaN     roc_auc        1.958025            NaN   516.922225                 0.179662                     NaN          33.029025            2       True         70
# 50                 LightGBM_BAG_L1       0.735133   0.738057     roc_auc        0.152788       0.693268     3.140782                 0.152788                0.693268           3.140782            1       True          2
# 51            CatBoost_r177_BAG_L1       0.735107   0.738772     roc_auc        0.034713       0.050316    18.313763                 0.034713                0.050316          18.313763            1       True          7
# 52             CatBoost_r13_BAG_L1       0.735106   0.738778     roc_auc        0.058474       0.079525    54.216267                 0.058474                0.079525          54.216267            1       True         15
# 53       LightGBM_r131_BAG_L1_FULL       0.735097        NaN     roc_auc        0.136616            NaN     8.117512                 0.136616                     NaN           8.117512            1       True         49
# 54              XGBoost_r33_BAG_L2       0.735096   0.737091     roc_auc        9.316598      28.073664  1180.251957                 0.563583                1.436779          24.495910            2       True         35
# 55       LightGBM_r131_BAG_L2_FULL       0.735095        NaN     roc_auc        1.866796            NaN   491.245359                 0.088432                     NaN           7.352159            2       True         71
# 56        CatBoost_r13_BAG_L1_FULL       0.735078        NaN     roc_auc        0.013256            NaN    14.071583                 0.013256                     NaN          14.071583            1       True         55
# 57                  XGBoost_BAG_L1       0.735034   0.737853     roc_auc        0.338260       0.520581     5.297058                 0.338260                0.520581           5.297058            1       True          4
# 58  NeuralNetTorch_r22_BAG_L2_FULL       0.735033        NaN     roc_auc        2.059455            NaN   508.317085                 0.281091                     NaN          24.423884            2       True         74
# 59            LightGBMLarge_BAG_L1       0.734907   0.736962     roc_auc        0.300258       1.556226     7.387065                 0.300258                1.556226           7.387065            1       True          6
# 60         XGBoost_r89_BAG_L1_FULL       0.734760        NaN     roc_auc        0.054517            NaN     1.304857                 0.054517                     NaN           1.304857            1       True         57
# ...
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/6.2 GB
# 	2.26s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/6.1 GB
# 	1.88s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	38.76s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.51s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/5.9 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	37.71s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.9 GB
# 	6.34s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	5.17s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/5.8 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	58.6s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/5.8 GB
# 	8.89s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	21.01s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/5.9 GB
# 	11.65s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/5.9 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	65.32s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	4.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	46.26s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	16.41s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.9 GB
# 	6.37s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.43s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/5.8 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	441.6s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.3 GB
# 	3.6s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/5.3 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	267.84s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r50_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	14.87s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r194_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	0.99s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r69_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	42.21s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r14_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/5.5 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	16.94s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r161_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.3 GB
# 	38.6s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r70_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.15s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBM_r96_BAG_L1': 0.304, 'CatBoost_r69_BAG_L1': 0.174, 'XGBoost_BAG_L1': 0.087, 'NeuralNetTorch_BAG_L1': 0.087, 'CatBoost_r137_BAG_L1': 0.087, 'NeuralNetTorch_r30_BAG_L1': 0.087, 'LightGBM_r130_BAG_L1': 0.087, 'LightGBM_r188_BAG_L1': 0.043, 'CatBoost_r50_BAG_L1': 0.043}
# 	16.5s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.3 GB
# 	2.23s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.3 GB
# 	2.08s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=1.0/5.3 GB
# 	8.11s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.9s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.3 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	15.62s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.6/5.5 GB
# 	6.56s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=1.0/5.4 GB
# 	2.88s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.5 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	53.44s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.6/5.5 GB
# 	8.62s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=1.1/5.4 GB
# 	13.38s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.3 GB
# 	5.0s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.4 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	39.67s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=1.0/5.4 GB
# 	5.56s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	15.85s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=1.1/5.4 GB
# 	10.49s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.6/5.3 GB
# 	6.33s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.78s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.4 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	219.28s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.6/5.7 GB
# 	3.33s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.7 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	28.19s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r50_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	4.92s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r194_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.09s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r69_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.9/5.7 GB
# 	12.22s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r14_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.7 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	11.1s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBM_r96_BAG_L1': 0.28, 'CatBoost_r69_BAG_L1': 0.16, 'XGBoost_BAG_L1': 0.08, 'NeuralNetTorch_BAG_L1': 0.08, 'CatBoost_r137_BAG_L1': 0.08, 'NeuralNetTorch_r30_BAG_L1': 0.08, 'LightGBM_r130_BAG_L1': 0.08, 'LightGBM_r188_BAG_L1': 0.04, 'XGBoost_BAG_L2': 0.04, 'XGBoost_r33_BAG_L2': 0.04, 'CatBoost_r137_BAG_L2': 0.04}
# 	27.49s	 = Training   runtime
# Refit complete, total runtime = 1650.28s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_out_v2")
#                             model  score_test  score_val eval_metric  \
# 0       NeuralNetTorch_r79_BAG_L2    0.738788   0.738108     roc_auc
# 1  NeuralNetTorch_r86_BAG_L2_FULL    0.738717        NaN     roc_auc
# 2  NeuralNetTorch_r30_BAG_L2_FULL    0.738688        NaN     roc_auc
# 3       NeuralNetTorch_r22_BAG_L2    0.738684   0.737727     roc_auc
# 4       NeuralNetTorch_r30_BAG_L2    0.738652   0.735921     roc_auc
#
#    pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  \
# 0       24.580137      49.863299  3232.080051                 2.092497
# 1        4.946870            NaN  1189.845305                 0.345571
# 2        5.059685            NaN  1380.939982                 0.458386
# 3       24.586394      50.066212  3257.988622                 2.098754
# 4       24.933953      50.264213  3576.961106                 2.446313
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                2.259359         137.692484            2       True
# 1                     NaN          28.187851            2       True
# 2                     NaN         219.282528            2       True
# 3                2.462272         163.601055            2       True
# 4                2.660273         482.573539            2       True
#
#    fit_order
# 0         35
# 1         99
# 2         97
# 3         39
# 4         45

# %%
# --- 2. 피처 중요도 ---
fi = predictor.feature_importance(data=train_data.sample(n=min(5000, len(train_df)), random_state=42))
fi.to_excel('fi11.xlsx')
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['ID']
# Computing feature importance via permutation shuffling for 61 features using 5000 rows with 5 shuffle sets...
# 	1049.1s	= Expected runtime (209.82s per shuffle set)
# 	747.75s	= Actual runtime (Completed 5 of 5 shuffle sets)

# %%
# --- 3. 제출 파일 생성 ---
# submission = pd.read_csv('../Data/sample_submission.csv')
# submission['probability'] = final_probs.values

# # 현재 시간 가져오기 (예: 0206_1031)
# now = datetime.now().strftime('%m%d_%H%M')
# file_name = f"{now}_submission.csv"
# submission.to_csv(file_name, index=False)

# print(f"학습 및 예측이 완료되었습니다. 결과가 {file_name}에 저장되었습니다.")

# %%
import random
import os
import numpy as np
import pandas as pd
from datetime import datetime
from autogluon.tabular import TabularPredictor

random.seed(42)
os.environ['PYTHONHASHSEED'] = str(42)
np.random.seed(42)

# ==========================================
# 1. 데이터 로드
# ==========================================

train_df = pd.read_csv('../Data/train.csv')
test_df = pd.read_csv('../Data/test.csv')
target = '임신 성공 여부'

# ==========================================
# 2. 파생변수 생성
# ==========================================

def derive_features(df):

    age_order = {'만18-34세': 1, '만35-37세': 2, '만38-39세': 3, '만40-42세': 4, '만43-44세': 5, '만45-50세': 6, '알 수 없음': 0}
    df['나이_순서'] = df['시술 당시 나이'].map(age_order)
    df['나이x배아'] = df['나이_순서'] * df['이식된 배아 수']
    df['연령별 배아 효율'] = df['이식된 배아 수'] / (df['나이_순서'] + 1e-5) # '나이가 적으면서 배아가 많은 그룹' vs '나이가 많으면서 배아가 적은 그룹' 강조

    df['배아 발달 기간'] = df['배아 이식 경과일'] - df['난자 혼합 경과일']
    df['이식 비중'] = df['이식된 배아 수'] / (df['이식된 배아 수'] + df['저장된 배아 수'] + 1e-5)

    oocyte_cols = ['수집된 신선 난자 수', '혼합된 난자 수', '기증자 정자와 혼합된 난자 수', '해동 난자 수']
    df['총 난자 수'] = df[oocyte_cols].fillna(0).sum(axis=1)
    df['배아 손실률'] = (df['총 난자 수'] - df['총 생성 배아 수']) / df['총 난자 수']
    
    df['배아 생성 효율'] = df['저장된 배아 수'] / (df['저장된 신선 난자 수'] + 1e-6)
    df['수정 효율'] = df['총 생성 배아 수'] / (df['혼합된 난자 수'] + 1e-6)
    df['선별 효율'] = df['저장된 배아 수'] / (df['총 생성 배아 수'] + 1e-6)
    
    def categorize_age_optimized(age_label):
        if age_label in ['만35-37세', '만38-39세']:
            return 1  # Middle
        elif age_label in ['만40-42세', '만43-44세', '만45-50세']:
            return 2  # Senior
        else:
            return 0  # '만18-34세'와 '알 수 없음'을 모두 0으로 처리
        
    df['나이_세분화'] = df['시술 당시 나이'].apply(categorize_age_optimized)

    def clean_treatment(text): 
        text = str(text).upper()
        if 'ICSI' in text:
            return 'ICSI'
        if 'IVF' in text:
            return 'IVF'
        if 'IUI' in text:
            return 'IUI'
        return 'Other'

    df['시술유형_정제'] = df['특정 시술 유형'].apply(clean_treatment)
    
    drop_cols = ['특정 시술 유형', '시술 유형', 'DI 출산 횟수', 'DI 임신 횟수','대리모 여부', '난자 해동 경과일', '배아 해동 경과일',
                 '난자 기증자 나이', '저장된 신선 난자 수', 'PGD 시술 여부', '난자 혼합 경과일',
                 '불임 원인 - 정자 운동성', '불임 원인 - 정자 형태', '불임 원인 - 자궁경부 문제', '불임 원인 - 정자 농도', '불임 원인 - 정자 면역학적 요인',
                '부부 주 불임 원인', '남성 주 불임 원인', '남성 부 불임 원인', '여성 주 불임 원인', '부부 부 불임 원인', '여성 부 불임 원인']
    df.drop(drop_cols, axis=1, inplace=True)
    
    return df

train_df = derive_features(train_df)
test_df = derive_features(test_df)

# ==========================================
# 3. 모델 학습 설정
# ==========================================

# 불균형 비율 계산 (190123 / 66228 = 약 2.87)
scale_weight = 190123 / 66228

custom_hyperparameters = {
    'GBM': [
        {'is_unbalance': True, 'ag_args': {'name_suffix': '_Unbal'}}, # LGBM 전용 불균형 옵션
        {'scale_pos_weight': scale_weight, 'learning_rate': 0.03, 'ag_args': {'name_suffix': '_Weighted'}},
        {'extra_trees': True, 'ag_args': {'name_suffix': '_XT'}} # 변동성 부여
    ],
    'XGB': [
        {'scale_pos_weight': scale_weight, 'max_depth': 6, 'ag_args': {'name_suffix': '_Weighted'}},
        {'max_depth': 8, 'learning_rate': 0.01, 'ag_args': {'name_suffix': '_Deep'}}
    ],
    'NN_TORCH': [
        {'weight_estimation': True}, # NeuralNet 불균형 가중치
        {'activation': 'elu', 'dropout_prob': 0.15}
    ]
}

predictor = TabularPredictor(
    label=target, 
    eval_metric='roc_auc',
    path='ag_models_out',
).fit(
    train_data=train_df,
    time_limit=3600 * 3,
    presets='best_quality',
    ag_args_fit={'num_gpus': 1},
    included_model_types=['GBM', 'CAT', 'XGB', 'RF', 'XT', 'NN_TORCH'],
    num_stack_levels=2,
    num_bag_folds=5,
    refit_full=True
)

# ==========================================
# 4. 예측 (Test Data 활용) - 최종 결과를 확률로 출력 (Positive 클래스에 대한 확률만 추출)
# ==========================================

pred_probs = predictor.predict_proba(test_df)
final_probs = pred_probs.iloc[:, 1]
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="ag_models_out"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.11.14
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 25.2.0: Tue Nov 18 21:09:40 PST 2025; root:xnu-12377.61.12~1/RELEASE_ARM64_T6000
# CPU Count:          10
# Pytorch Version:    2.9.1
# CUDA Version:       CUDA is not available
# GPU Count:          WARNING: Exception was raised when calculating GPU count (AssertionError)
# Memory Avail:       3.24 GB / 16.00 GB (20.3%)
# Disk Space Avail:   187.75 GB / 460.43 GB (40.8%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=2, num_bag_folds=5, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 2700s of the 10800s of remaining time (25%).
# DyStack: Disabling memory safe fit mode in DyStack because GPUs were detected and num_gpus='auto' (GPUs cannot be used in memory safe fit mode). If you want to use memory safe fit mode, manually set `num_gpus=0`.
# Running DyStack sub-fit ...
# Beginning AutoGluon training ... Time limit = 2700s
# AutoGluon will save models to "/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_out/ds_sub_fit/sub_fit_ho"
# Train Data Rows:    227867
# Train Data Columns: 58
# Label Column:       임신 성공 여부
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    3630.66 MB
# 	Train Data (Original)  Memory Usage: 386.40 MB (10.6% of available memory)
# 	Warning: Data size prior to feature transformation consumes 10.6% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 9 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 1): ['불임 원인 - 여성 요인']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 1): ['ID']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['ID']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 32 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 검사 사용 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', ...]
# 		('int', [])    :  8 | ['배란 자극 여부', '불명확 불임 원인', '불임 원인 - 난관 질환', '불임 원인 - 남성 요인', '불임 원인 - 배란 장애', ...]
# 		('object', []) : 16 | ['시술 시기 코드', '시술 당시 나이', '배란 유도 유형', '배아 생성 주요 이유', '총 시술 횟수', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 16 | ['시술 시기 코드', '시술 당시 나이', '배란 유도 유형', '배아 생성 주요 이유', '총 시술 횟수', ...]
# 		('float', [])     : 29 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', '미세주입된 난자 수', ...]
# 		('int', [])       :  2 | ['나이_순서', '나이_세분화']
# 		('int', ['bool']) :  9 | ['배란 자극 여부', '착상 전 유전 검사 사용 여부', '불명확 불임 원인', '불임 원인 - 난관 질환', '불임 원인 - 남성 요인', ...]
# 	1.5s = Fit runtime
# 	56 features in original data used to generate 56 features in processed data.
# 	Train Data (Processed) Memory Usage: 59.33 MB (1.7% of available memory)
# Data preprocessing and feature engineering runtime = 1.72s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 3 stack levels (L1 to L3) ...
# Included models: ['GBM', 'CAT', 'XGB', 'RF', 'XT', 'NN_TORCH'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 85 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1198.93s of the 2698.27s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=14.46%)
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=7147, ip=127.0.0.1)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
#     return lgb.train(**train_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 3660, in __init__
#     _safe_call(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=7147, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 473, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 360, in _fit
#     self.model = train_lgb_model(early_stopping_callback_kwargs=early_stopping_callback_kwargs, **train_params)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
#     return lgb.train(**train_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/engine.py", line 301, in train
#     booster.add_valid(valid_set, name_valid_set)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 4058, in add_valid
#     data.construct()._handle,
#     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 2539, in construct
#     self._lazy_init(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 2153, in _lazy_init
#     raise TypeError(f"Wrong type({type(name).__name__}) or unknown name({name}) in categorical_feature")
# TypeError: Wrong type(str) or unknown name(시술 시기 코드) in categorical_feature
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2201, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2085, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 393, in _fit
#     self._fit_folds(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 887, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 796, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 713, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 666, in _process_fold_results
#     raise processed_exception
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 619, in _process_fold_results
#     out = self.ray.get(finished)
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py", line 2972, in get
#     values, debugger_breakpoint = worker.get_objects(
#                                   ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py", line 1031, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=7147, ip=127.0.0.1)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
#     return lgb.train(**train_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 3660, in __init__
#     _safe_call(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=7147, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 473, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 360, in _fit
#     self.model = train_lgb_model(early_stopping_callback_kwargs=early_stopping_callback_kwargs, **train_params)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
#     return lgb.train(**train_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/engine.py", line 301, in train
#     booster.add_valid(valid_set, name_valid_set)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 4058, in add_valid
#     data.construct()._handle,
#     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 2539, in construct
#     self._lazy_init(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 2153, in _lazy_init
#     raise TypeError(f"Wrong type({type(name).__name__}) or unknown name({name}) in categorical_feature")
# TypeError: Wrong type(str) or unknown name(시술 시기 코드) in categorical_feature
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1192.57s of the 2691.90s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=13.95%)
# 	Warning: Exception caused LightGBM_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=7146, ip=127.0.0.1)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
#     return lgb.train(**train_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 3660, in __init__
#     _safe_call(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=7146, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 473, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 360, in _fit
#     self.model = train_lgb_model(early_stopping_callback_kwargs=early_stopping_callback_kwargs, **train_params)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
#     return lgb.train(**train_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/engine.py", line 301, in train
#     booster.add_valid(valid_set, name_valid_set)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 4058, in add_valid
#     data.construct()._handle,
#     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 2539, in construct
#     self._lazy_init(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 2153, in _lazy_init
#     raise TypeError(f"Wrong type({type(name).__name__}) or unknown name({name}) in categorical_feature")
# TypeError: Wrong type(str) or unknown name(시술 시기 코드) in categorical_feature
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2201, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2085, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 393, in _fit
#     self._fit_folds(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 887, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 796, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 713, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 666, in _process_fold_results
#     raise processed_exception
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 619, in _process_fold_results
#     out = self.ray.get(finished)
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py", line 2972, in get
#     values, debugger_breakpoint = worker.get_objects(
#                                   ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py", line 1031, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=7146, ip=127.0.0.1)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
#     return lgb.train(**train_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 3660, in __init__
#     _safe_call(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=7146, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 473, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 360, in _fit
#     self.model = train_lgb_model(early_stopping_callback_kwargs=early_stopping_callback_kwargs, **train_params)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
#     return lgb.train(**train_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/engine.py", line 301, in train
#     booster.add_valid(valid_set, name_valid_set)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 4058, in add_valid
#     data.construct()._handle,
#     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 2539, in construct
#     self._lazy_init(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 2153, in _lazy_init
#     raise TypeError(f"Wrong type({type(name).__name__}) or unknown name({name}) in categorical_feature")
# TypeError: Wrong type(str) or unknown name(시술 시기 코드) in categorical_feature
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1190.34s of the 2689.68s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/2.7 GB
# 	Warning: Reducing model 'n_estimators' from 300 -> 189 due to low memory. Expected memory usage reduced from 23.75% -> 15.0% of available memory...
# 	0.7253	 = Validation score   (roc_auc)
# 	8.63s	 = Training   runtime
# 	3.99s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1177.23s of the 2676.56s of remaining time.
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 1.061 GB out of 2.606 GB available memory (40.716%)... (50.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.07 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/2.6 GB
# 	Warning: Reducing model 'n_estimators' from 300 -> 173 due to low memory. Expected memory usage reduced from 25.88% -> 15.0% of available memory...
# 	0.7254	 = Validation score   (roc_auc)
# 	7.68s	 = Training   runtime
# 	3.73s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1165.38s of the 2664.72s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 2 folds in parallel instead (Estimated 31.51% memory usage per fold, 63.02%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=31.51%)
# 	Warning: Exception caused CatBoost_BAG_L1 to fail during training... Skipping this model.
# 		Failed to deserialize exception. Refer to https://docs.ray.io/en/latest/ray-core/objects/serialization.html#custom-serializers-for-exceptions for more information.
# Original exception:
# ray.exceptions.RayTaskError: ray::_ray_fit() (pid=7151, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 473, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/catboost/catboost_model.py", line 236, in _fit
#     params["iterations"] = self._estimate_iter_in_time_gpu(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/catboost/catboost_model.py", line 292, in _estimate_iter_in_time_gpu
#     sample_model.fit(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/catboost/core.py", line 5245, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/catboost/core.py", line 2410, in _fit
#     self._train(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/catboost/core.py", line 1790, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 5023, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 5072, in _catboost._CatBoost._train
# _catboost.CatBoostError: catboost/libs/train_lib/trainer_env.cpp:9: Environment for task type [GPU] not found
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2201, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2085, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 393, in _fit
#     self._fit_folds(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 887, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 796, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 713, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 666, in _process_fold_results
#     raise processed_exception
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 619, in _process_fold_results
#     out = self.ray.get(finished)
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py", line 2972, in get
#     values, debugger_breakpoint = worker.get_objects(
#                                   ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py", line 1033, in get_objects
#     raise value
# ray.exceptions.UnserializableException: Failed to deserialize exception. Refer to https://docs.ray.io/en/latest/ray-core/objects/serialization.html#custom-serializers-for-exceptions for more information.
# Original exception:
# ray.exceptions.RayTaskError: ray::_ray_fit() (pid=7151, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 473, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/catboost/catboost_model.py", line 236, in _fit
#     params["iterations"] = self._estimate_iter_in_time_gpu(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/catboost/catboost_model.py", line 292, in _estimate_iter_in_time_gpu
#     sample_model.fit(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/catboost/core.py", line 5245, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/catboost/core.py", line 2410, in _fit
#     self._train(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/catboost/core.py", line 1790, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 5023, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 5072, in _catboost._CatBoost._train
# _catboost.CatBoostError: catboost/libs/train_lib/trainer_env.cpp:9: Environment for task type [GPU] not found
#
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1163.06s of the 2662.40s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/2.8 GB
# 	Warning: Reducing model 'n_estimators' from 300 -> 182 due to low memory. Expected memory usage reduced from 24.66% -> 15.0% of available memory...
# 	0.7294	 = Validation score   (roc_auc)
# 	5.49s	 = Training   runtime
# 	3.72s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1153.42s of the 2652.75s of remaining time.
# 	Warning: Potentially not enough memory to safely train model. Estimated to require 1.061 GB out of 2.637 GB available memory (40.243%)... (50.000% of avail memory is the max safe size)
# 	To avoid this warning, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.06 to avoid the warning)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.1/2.6 GB
# 	Warning: Reducing model 'n_estimators' from 300 -> 176 due to low memory. Expected memory usage reduced from 25.5% -> 15.0% of available memory...
# 	0.7297	 = Validation score   (roc_auc)
# 	5.46s	 = Training   runtime
# 	3.64s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1143.87s of the 2643.21s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 2 folds in parallel instead (Estimated 20.10% memory usage per fold, 40.20%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=20.10%)
# 	0.7383	 = Validation score   (roc_auc)
# 	77.08s	 = Training   runtime
# 	1.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1064.87s of the 2564.21s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=11.84%)
# 	0.7362	 = Validation score   (roc_auc)
# 	830.58s	 = Training   runtime
# 	3.32s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 231.52s of the 1730.86s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.12% memory usage per fold, 64.48%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=16.12%)
# 	Warning: Exception caused LightGBMLarge_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=9119, ip=127.0.0.1)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
#     return lgb.train(**train_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 3660, in __init__
#     _safe_call(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=9119, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 473, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 360, in _fit
#     self.model = train_lgb_model(early_stopping_callback_kwargs=early_stopping_callback_kwargs, **train_params)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
#     return lgb.train(**train_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/engine.py", line 301, in train
#     booster.add_valid(valid_set, name_valid_set)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 4058, in add_valid
#     data.construct()._handle,
#     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 2539, in construct
#     self._lazy_init(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 2153, in _lazy_init
#     raise TypeError(f"Wrong type({type(name).__name__}) or unknown name({name}) in categorical_feature")
# TypeError: Wrong type(str) or unknown name(시술 시기 코드) in categorical_feature
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2201, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2085, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 393, in _fit
#     self._fit_folds(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 887, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 796, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 713, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 666, in _process_fold_results
#     raise processed_exception
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 619, in _process_fold_results
#     out = self.ray.get(finished)
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py", line 2972, in get
#     values, debugger_breakpoint = worker.get_objects(
#                                   ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py", line 1031, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=9119, ip=127.0.0.1)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
#     return lgb.train(**train_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 3660, in __init__
#     _safe_call(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=9119, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 473, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 360, in _fit
#     self.model = train_lgb_model(early_stopping_callback_kwargs=early_stopping_callback_kwargs, **train_params)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
# ...
#     _safe_call(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=25010, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 473, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 360, in _fit
#     self.model = train_lgb_model(early_stopping_callback_kwargs=early_stopping_callback_kwargs, **train_params)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/lgb/lgb_utils.py", line 134, in train_lgb_model
#     return lgb.train(**train_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/engine.py", line 301, in train
#     booster.add_valid(valid_set, name_valid_set)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 4058, in add_valid
#     data.construct()._handle,
#     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 2539, in construct
#     self._lazy_init(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/lightgbm/basic.py", line 2153, in _lazy_init
#     raise TypeError(f"Wrong type({type(name).__name__}) or unknown name({name}) in categorical_feature")
# TypeError: Wrong type(str) or unknown name(시술 시기 코드) in categorical_feature
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 38.17s of the 38.17s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=8.60%)
# 	Time limit exceeded... Skipping NeuralNetTorch_r86_BAG_L1.
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 33.01s of the 33.01s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 4 folds in parallel instead (Estimated 19.69% memory usage per fold, 78.78%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=19.69%)
# 	Warning: Exception caused CatBoost_r50_BAG_L1 to fail during training... Skipping this model.
# 		Failed to deserialize exception. Refer to https://docs.ray.io/en/latest/ray-core/objects/serialization.html#custom-serializers-for-exceptions for more information.
# Original exception:
# ray.exceptions.RayTaskError: ray::_ray_fit() (pid=25015, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 473, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/catboost/catboost_model.py", line 236, in _fit
#     params["iterations"] = self._estimate_iter_in_time_gpu(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/catboost/catboost_model.py", line 292, in _estimate_iter_in_time_gpu
#     sample_model.fit(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/catboost/core.py", line 5245, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/catboost/core.py", line 2410, in _fit
#     self._train(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/catboost/core.py", line 1790, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 5023, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 5072, in _catboost._CatBoost._train
# _catboost.CatBoostError: catboost/libs/train_lib/trainer_env.cpp:9: Environment for task type [GPU] not found
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2201, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2085, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 393, in _fit
#     self._fit_folds(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 887, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 796, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 713, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 666, in _process_fold_results
#     raise processed_exception
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 619, in _process_fold_results
#     out = self.ray.get(finished)
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py", line 2972, in get
#     values, debugger_breakpoint = worker.get_objects(
#                                   ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py", line 1033, in get_objects
#     raise value
# ray.exceptions.UnserializableException: Failed to deserialize exception. Refer to https://docs.ray.io/en/latest/ray-core/objects/serialization.html#custom-serializers-for-exceptions for more information.
# Original exception:
# ray.exceptions.RayTaskError: ray::_ray_fit() (pid=25015, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 473, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1125, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/catboost/catboost_model.py", line 236, in _fit
#     params["iterations"] = self._estimate_iter_in_time_gpu(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/autogluon/tabular/models/catboost/catboost_model.py", line 292, in _estimate_iter_in_time_gpu
#     sample_model.fit(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/catboost/core.py", line 5245, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/catboost/core.py", line 2410, in _fit
#     self._train(
#   File "/opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/catboost/core.py", line 1790, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 5023, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 5072, in _catboost._CatBoost._train
# _catboost.CatBoostError: catboost/libs/train_lib/trainer_env.cpp:9: Environment for task type [GPU] not found
#
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 29.53s of the 29.53s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=11.94%)
# 	0.7389	 = Validation score   (roc_auc)
# 	29.29s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 771.88s of the -1.55s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/4.6 GB
# 	Ensemble Weights: {'XGBoost_r89_BAG_L1': 0.375, 'NeuralNetTorch_r79_BAG_L1': 0.167, 'NeuralNetTorch_BAG_L1': 0.125, 'XGBoost_r194_BAG_L1': 0.125, 'XGBoost_BAG_L1': 0.083, 'NeuralNetTorch_r22_BAG_L1': 0.083, 'RandomForestGini_BAG_L1': 0.042}
# 	0.7403	 = Validation score   (roc_auc)
# 	11.46s	 = Training   runtime
# 	0.03s	 = Validation runtime
# AutoGluon training complete, total runtime = 7733.91s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 2894.0 rows/s (51271 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	10.71s	 = Training   runtime
# 	5.67s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	10.31s	 = Training   runtime
# 	5.25s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	7.76s	 = Training   runtime
# 	5.3s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	7.5s	 = Training   runtime
# 	5.12s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=1
# 	2.21s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=1, mem=0.3/3.9 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	139.7s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=1, mem=0.3/4.0 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	139.0s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=1, mem=0.3/4.1 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	247.25s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=1
# 	5.36s	 = Training   runtime
# Fitting model: ExtraTrees_r42_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	35.2s	 = Training   runtime
# 	6.33s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	28.15s	 = Training   runtime
# 	3.53s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=1
# 	2.53s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=1, mem=0.3/4.1 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	19.29s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r194_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=1
# 	1.4s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'XGBoost_r89_BAG_L1': 0.375, 'NeuralNetTorch_r79_BAG_L1': 0.167, 'NeuralNetTorch_BAG_L1': 0.125, 'XGBoost_r194_BAG_L1': 0.125, 'XGBoost_BAG_L1': 0.083, 'NeuralNetTorch_r22_BAG_L1': 0.083, 'RandomForestGini_BAG_L1': 0.042}
# 	11.46s	 = Training   runtime
# Refit complete, total runtime = 561.66s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_out")

# %%
# --- 1. 리더보드 (오름차순 정렬) ---
lb = predictor.leaderboard(silent=True)
display(lb.sort_values(by='score_val', ascending=False))
# Out:
#                              model  score_val eval_metric  pred_time_val  \
# 0              WeightedEnsemble_L2   0.740336     roc_auc      22.282046
# 1               XGBoost_r89_BAG_L1   0.739357     roc_auc       1.580842
# 2                   XGBoost_BAG_L1   0.738910     roc_auc       1.525679
# 3              XGBoost_r194_BAG_L1   0.738903     roc_auc       0.545960
# 4        NeuralNetTorch_r79_BAG_L1   0.737879     roc_auc       4.864224
# 5            NeuralNetTorch_BAG_L1   0.737007     roc_auc       4.299485
# 6               XGBoost_r33_BAG_L1   0.736865     roc_auc       4.832037
# 7        NeuralNetTorch_r22_BAG_L1   0.735985     roc_auc       3.758694
# 8            ExtraTreesEntr_BAG_L1   0.732092     roc_auc       5.120908
# 9            ExtraTreesGini_BAG_L1   0.731530     roc_auc       5.304253
# 10       NeuralNetTorch_r30_BAG_L1   0.728746     roc_auc       4.198884
# 11         RandomForestEntr_BAG_L1   0.727762     roc_auc       5.246124
# 12         RandomForestGini_BAG_L1   0.727507     roc_auc       5.673602
# 13           ExtraTrees_r42_BAG_L1   0.722335     roc_auc       6.328387
# 14        RandomForest_r195_BAG_L1   0.699625     roc_auc       3.532438
# 15   RandomForest_r195_BAG_L1_FULL        NaN     roc_auc       3.532438
# 16      ExtraTreesEntr_BAG_L1_FULL        NaN     roc_auc       5.120908
# 17    RandomForestEntr_BAG_L1_FULL        NaN     roc_auc       5.246124
# 18      ExtraTreesGini_BAG_L1_FULL        NaN     roc_auc       5.304253
# 19    RandomForestGini_BAG_L1_FULL        NaN     roc_auc       5.673602
# 20      ExtraTrees_r42_BAG_L1_FULL        NaN     roc_auc       6.328387
# 21         XGBoost_r89_BAG_L1_FULL        NaN     roc_auc            NaN
# 22         XGBoost_r33_BAG_L1_FULL        NaN     roc_auc            NaN
# 23        XGBoost_r194_BAG_L1_FULL        NaN     roc_auc            NaN
# 24             XGBoost_BAG_L1_FULL        NaN     roc_auc            NaN
# 25        WeightedEnsemble_L2_FULL        NaN     roc_auc            NaN
# 26  NeuralNetTorch_r79_BAG_L1_FULL        NaN     roc_auc            NaN
# 27  NeuralNetTorch_r30_BAG_L1_FULL        NaN     roc_auc            NaN
# 28  NeuralNetTorch_r22_BAG_L1_FULL        NaN     roc_auc            NaN
# 29      NeuralNetTorch_BAG_L1_FULL        NaN     roc_auc            NaN
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   7179.077192                0.033559          11.462259            2
# 1    133.542065                1.580842         133.542065            1
# 2     98.548495                1.525679          98.548495            1
# 3     29.285895                0.545960          29.285895            1
# 4   2356.947834                4.864224        2356.947834            1
# 5   2127.915156                4.299485        2127.915156            1
# 6    267.196338                4.832037         267.196338            1
# 7   2410.661886                3.758694        2410.661886            1
# 8      7.501380                5.120908           7.501380            1
# 9      7.761490                5.304253           7.761490            1
# 10    94.778705                4.198884          94.778705            1
# 11    10.305377                5.246124          10.305377            1
# 12    10.713602                5.673602          10.713602            1
# 13    35.196244                6.328387          35.196244            1
# 14    28.151291                3.532438          28.151291            1
# 15    28.151291                3.532438          28.151291            1
# 16     7.501380                5.120908           7.501380            1
# 17    10.305377                5.246124          10.305377            1
# 18     7.761490                5.304253           7.761490            1
# 19    10.713602                5.673602          10.713602            1
# 20    35.196244                6.328387          35.196244            1
# 21     2.525070                     NaN           2.525070            1
# 22     5.355746                     NaN           5.355746            1
# 23     1.402691                     NaN           1.402691            1
# 24     2.210913                     NaN           2.210913            1
# 25   554.262478                     NaN          11.462259            2
# 26   138.998636                     NaN         138.998636            1
# 27    19.287458                     NaN          19.287458            1
# 28   247.252054                     NaN         247.252054            1
# 29   139.697253                     NaN         139.697253            1
#
#     can_infer  fit_order
# 0        True         15
# 1        True         12
# 2        True          5
# 3        True         14
# 4        True          7
# 5        True          6
# 6        True          9
# 7        True          8
# 8        True          4
# 9        True          3
# 10       True         13
# 11       True          2
# 12       True          1
# 13       True         10
# 14       True         11
# 15       True         26
# 16       True         19
# 17       True         17
# 18       True         18
# 19       True         16
# 20       True         25
# 21       True         27
# 22       True         24
# 23       True         29
# 24       True         20
# 25       True         30
# 26       True         22
# 27       True         28
# 28       True         23
# 29       True         21

# %%
# --- 2. 피처 중요도 ---
fi = predictor.feature_importance(data=train_df.sample(n=min(5000, len(train_df)), random_state=42))
display(fi)
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['ID', '불임 원인 - 여성 요인']
# Computing feature importance via permutation shuffling for 56 features using 5000 rows with 5 shuffle sets...
# 	645.13s	= Expected runtime (129.03s per shuffle set)
# 	398.78s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                   importance    stddev       p_value  n  p99_high   p99_low
# 파트너 정자와 혼합된 난자 수    0.003495  0.000080  3.232168e-08  5  0.003659  0.003331
# 미세주입에서 생성된 배아 수     0.002947  0.000143  6.568078e-07  5  0.003240  0.002653
# 혼합된 난자 수            0.004235  0.000237  1.174966e-06  5  0.004724  0.003747
# 총 난자 수              0.005140  0.000296  1.310661e-06  5  0.005749  0.004531
# 불명확 불임 원인           0.001059  0.000066  1.835840e-06  5  0.001196  0.000923
# 미세주입된 난자 수          0.002985  0.000199  2.355443e-06  5  0.003394  0.002575
# 수집된 신선 난자 수         0.005338  0.000366  2.630219e-06  5  0.006092  0.004585
# 총 시술 횟수             0.003209  0.000240  3.728653e-06  5  0.003703  0.002715
# 수정 효율               0.005455  0.000446  5.330351e-06  5  0.006374  0.004536
# 미세주입 후 저장된 배아 수     0.000978  0.000080  5.365486e-06  5  0.001143  0.000813
# IVF 시술 횟수           0.005614  0.000511  8.176042e-06  5  0.006667  0.004561
# 나이x배아               0.033737  0.003287  1.067636e-05  5  0.040505  0.026970
# 배아 이식 경과일           0.009740  0.000969  1.159697e-05  5  0.011735  0.007745
# 시술유형_정제             0.001845  0.000185  1.189615e-05  5  0.002225  0.001465
# 배아 생성 효율            0.001220  0.000127  1.409230e-05  5  0.001483  0.000958
# 클리닉 내 총 시술 횟수       0.004993  0.000539  1.599469e-05  5  0.006102  0.003884
# 미세주입 배아 이식 수        0.001400  0.000153  1.666007e-05  5  0.001714  0.001086
# 불임 원인 - 배란 장애       0.000819  0.000094  2.079158e-05  5  0.001013  0.000624
# 배아 발달 기간            0.006147  0.000758  2.722922e-05  5  0.007708  0.004585
# 시술 당시 나이            0.002676  0.000330  2.724416e-05  5  0.003356  0.001996
# 선별 효율               0.003069  0.000384  2.881304e-05  5  0.003860  0.002278
# 불임 원인 - 남성 요인       0.002842  0.000372  3.444463e-05  5  0.003608  0.002076
# IVF 출산 횟수           0.000758  0.000101  3.719399e-05  5  0.000966  0.000550
# 기증자 정자와 혼합된 난자 수    0.000609  0.000082  3.864735e-05  5  0.000778  0.000440
# 불임 원인 - 자궁내막증       0.000645  0.000088  3.981593e-05  5  0.000825  0.000464
# 정자 기증자 나이           0.001296  0.000177  4.068462e-05  5  0.001660  0.000932
# 연령별 배아 효율           0.019057  0.002708  4.765783e-05  5  0.024634  0.013481
# 총 생성 배아 수           0.006839  0.001020  5.756226e-05  5  0.008939  0.004740
# 착상 전 유전 검사 사용 여부    0.000602  0.000091  6.131278e-05  5  0.000790  0.000414
# 배아 손실률              0.006152  0.000955  6.761745e-05  5  0.008119  0.004185

# %%
# --- 3. 제출 파일 생성 ---
submission = pd.read_csv('../Data/sample_submission.csv')
submission['probability'] = final_probs.values

# 현재 시간 가져오기 (예: 0206_1031)
now = datetime.now().strftime('%m%d_%H%M')
file_name = f"{now}_submission.csv"
submission.to_csv(file_name, index=False)

print(f"학습 및 예측이 완료되었습니다. 결과가 {file_name}에 저장되었습니다.")
# Out:
# 학습 및 예측이 완료되었습니다. 결과가 0206_2005_submission.csv에 저장되었습니다.

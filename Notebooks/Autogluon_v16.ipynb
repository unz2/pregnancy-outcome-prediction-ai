# %%
import random
import os
import numpy as np
import pandas as pd
from datetime import datetime
from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

random.seed(42)
os.environ['PYTHONHASHSEED'] = str(42)
np.random.seed(42)

# ==========================================
# 1. 데이터 로드
# ==========================================

train_df = pd.read_csv('../Data/train.csv')
test_df = pd.read_csv('../Data/test.csv')
target = '임신 성공 여부'

# ==========================================
# 2. feature_engineering
# ==========================================

def feature_engineering(df):
    
    # 수치형 변환 ('회', ' 이상' 등을 제거하고 공백 정리 후 숫자형으로 변환)
    count_cols = [
        '총 시술 횟수', '클리닉 내 총 시술 횟수', '총 임신 횟수', '총 출산 횟수',
        'IVF 시술 횟수', 'DI 시술 횟수', 'IVF 임신 횟수', 'DI 임신 횟수',
        'IVF 출산 횟수', 'DI 출산 횟수', '총 생성 배아 수', '이식된 배아 수', 
        '미세주입된 난자 수', '미세주입에서 생성된 배아 수', '저장된 배아 수'
    ]
    
    for col in count_cols:
        if col in df.columns and df[col].dtype == 'object':
            df[col] = df[col].astype(str).str.replace(r'회| 이상', '', regex=True).str.strip()
            df[col] = pd.to_numeric(df[col], errors='coerce')

    
    # 시술 유형 DI에 대한 결측치 처리 (0으로 채우기)
    target_cols = [
            '총 생성 배아 수', '기증자 정자와 혼합된 난자 수', '파트너 정자와 혼합된 난자 수',
            '미세주입된 난자 수', '혼합된 난자 수', '저장된 신선 난자 수', '해동 난자 수',
            '해동된 배아 수', '미세주입 후 저장된 배아 수', '저장된 배아 수',
            '미세주입 배아 이식 수', '이식된 배아 수', '미세주입에서 생성된 배아 수',
            '수집된 신선 난자 수', '단일 배아 이식 여부', '착상 전 유전 진단 사용 여부', '대리모 여부',
            '기증 배아 사용 여부', '신선 배아 사용 여부', '동결 배아 사용 여부'
        ]
    existing_target_cols = [c for c in target_cols if c in df.columns]
    mask_di = df['시술 유형'] == 'DI'
    df.loc[mask_di, existing_target_cols] = df.loc[mask_di, existing_target_cols].fillna(0)

    
    # 배아 생성 이유 정제
    def clean_reason(row):
        if row['시술 유형'] == 'DI':
            return '해당없음'
    
        x = row['배아 생성 주요 이유']
        if pd.isna(x): return 'Unknown'
    
        x = str(x)
        if '시술용' in x: return '시술용'
        if '기증' in x: return '기증용'
        if '저장' in x: return '저장용'
        return 'Other'
    
    df['배아 생성 주요 이유'] = df.apply(clean_reason, axis=1)

    
    # 이진 분류 컬럼 결측 0으로 채우기
    binary_cols = ['PGS 시술 여부', 'PGD 시술 여부', '착상 전 유전 검사 사용 여부']
    df[binary_cols] = df[binary_cols].fillna(0)
    
    
    if '특정 시술 유형' in df.columns:
        df["BLASTOCYST_포함"] = df["특정 시술 유형"].str.contains("BLASTOCYST", case=False, na=False).astype(int)
        df["AH_포함"] = df["특정 시술 유형"].str.contains("AH", case=False, na=False).astype(int)
        
        def major_procedure(x):
            if pd.isna(x): return "Unknown"
            x = str(x).upper()

            # 1. ICSI (ICSI:IVF나 ICSI:ICSI 등을 모두 포함)
            if "ICSI" in x: return "ICSI"
            # 2. IVF (ICSI가 없으면서 IVF가 포함된 경우)
            if "IVF" in x: return "IVF"
            # 3. DI (기증자 인공수정)
            if "DI" in x: return "DI"
            # 4. IUI, ICI, IVI (모두 넓은 의미의 인공수정 계열)
            if any(keyword in x for keyword in ["IUI", "ICI", "IVI"]): return "IUI"
            # 5. 기타 (GIFT, FER 등 아주 적은 수의 데이터)
            if "UNKNOWN" in x: return "Unknown"
            return "Other"
        
        df["특정 시술 유형"] = df["특정 시술 유형"].apply(major_procedure)

    
    # 불임 원인 및 복잡도 계산
    female_cols = [
        '불임 원인 - 여성 요인', '불임 원인 - 난관 질환', '불임 원인 - 배란 장애', 
        '불임 원인 - 자궁경부 문제', '불임 원인 - 자궁내막증'
    ]
    male_cols = [
        '불임 원인 - 남성 요인', '불임 원인 - 정자 농도', '불임 원인 - 정자 운동성', 
        '불임 원인 - 정자 형태', '불임 원인 - 정자 면역학적 요인'
    ]
    infertility_cols = [
        "남성 주 불임 원인", "남성 부 불임 원인", "여성 주 불임 원인", "여성 부 불임 원인",
        "부부 주 불임 원인", "부부 부 불임 원인", "불명확 불임 원인",
        "불임 원인 - 난관 질환", "불임 원인 - 남성 요인", "불임 원인 - 배란 장애",
        "불임 원인 - 여성 요인", "불임 원인 - 자궁경부 문제", "불임 원인 - 자궁내막증",
        "불임 원인 - 정자 농도", "불임 원인 - 정자 면역학적 요인", "불임 원인 - 정자 운동성",
        "불임 원인 - 정자 형태"
    ]

    df['남성 결함 개수'] = df[male_cols].sum(axis=1)
    df['여성 결함 개수'] = df[female_cols].sum(axis=1)
    df['불임 원인 개수'] = df[infertility_cols].sum(axis=1)
    
    def infertility_complexity(count):
        if count == 0: return 'None'
        elif count == 1: return 'Single'
        elif count == 2: return 'Double'
        else: return 'Multiple'
    
    df['불임 원인 개수'] = df['불임 원인 개수'].apply(infertility_complexity)

    
    # 총 시술 횟수 -> 3구간으로 구간화
    def collapse_trials(x):
        if pd.isna(x): return 'Unknown'
        if x <= 0: return '0회' 
        elif 1 <= x <= 2: return '1–2회'
        elif 3 <= x <= 5: return '3–5회'
        else: return '6회 이상'

    df["총 시술 bin3"] = df["총 시술 횟수"].apply(collapse_trials)


    def div(num1, num2):
        return np.where(num2 == 0, -1, num1 / num2)

    if '시술 당시 나이' in df.columns:
        temp_age = df['시술 당시 나이'].astype(str).str.extract(r'(\d+)')[0].astype(float)
    else:
        temp_age = np.nan
    
    df['나이x이식배아'] = (temp_age + 1) * df['이식된 배아 수']
    df['연령별 배아 효율'] = div(df['이식된 배아 수'], (temp_age + 1))
    
    df['배아 생성 효율'] = div(df['총 생성 배아 수'], df['수집된 신선 난자 수'])
    df['배아 이식 비율'] = div(df['이식된 배아 수'], df['총 생성 배아 수'])
    df['배아 저장 비율'] = div(df['저장된 배아 수'], df['총 생성 배아 수'])
    
    df['이상적 배양 기간'] = df['배아 이식 경과일'].isin([3, 5]).astype(int)

    df['IVF 시술 대비 임신율'] = div(df['IVF 임신 횟수'], df['IVF 시술 횟수'])
    df['IVF 시술 대비 출산율'] = div(df['IVF 출산 횟수'], df['IVF 시술 횟수'])
    df['IVF 임신 유지력'] = div(df['IVF 출산 횟수'], df['IVF 임신 횟수'])

    df['DI 시술 대비 임신율'] = div(df['DI 임신 횟수'], df['DI 시술 횟수'])
    df['DI 시술 대비 출산율'] = div(df['DI 출산 횟수'], df['DI 시술 횟수'])
    df['DI 임신 유지력'] = div(df['DI 출산 횟수'], df['DI 임신 횟수'])

    
    # 배아 이식 상태 및 단계 (preprocess)
    embryo_stage_cols = [
        "단일 배아 이식 여부", "착상 전 유전 진단 사용 여부", "배아 생성 주요 이유",
        "총 생성 배아 수", "미세주입된 난자 수", "미세주입에서 생성된 배아 수",
        "이식된 배아 수", "미세주입 배아 이식 수", "저장된 배아 수",
        "미세주입 후 저장된 배아 수", "해동된 배아 수", "해동 난자 수",
        "수집된 신선 난자 수", "저장된 신선 난자 수", "혼합된 난자 수",
        "파트너 정자와 혼합된 난자 수", "기증자 정자와 혼합된 난자 수",
        "동결 배아 사용 여부", "신선 배아 사용 여부", "기증 배아 사용 여부", "대리모 여부",
    ]
    df["배아_이식_미도달"] = df[embryo_stage_cols].isna().all(axis=1).astype(int)
    df["배아_이식_여부"] = 1 - df["배아_이식_미도달"]

    def embryo_stage(row):
        if row['배아_이식_여부'] == 0: return '배아단계_미도달'
        elif pd.isna(row['총 생성 배아 수']) or row['총 생성 배아 수'] == 0: return '배아생성_실패'
        elif pd.isna(row['이식된 배아 수']) or row['이식된 배아 수'] == 0: return '이식_미실시'
        else: return '이식_완료'

    df['배아_진행_단계'] = df.apply(embryo_stage, axis=1)

    # 4.3 이식 배아 구간 (preprocess)
    def embryo_count_bin(count):
        if pd.isna(count) or count == 0: return '0개'
        elif count <= 2: return '1-2개'
        else: return '3개 이상'
    df['이식배아_구간'] = df['이식된 배아 수'].apply(embryo_count_bin)

    drop_cols = ['ID'] + female_cols + male_cols
    df.drop(columns=drop_cols, errors='ignore', inplace=True)
    
    return df

train_df = feature_engineering(train_df)
test_df = feature_engineering(test_df)

# ==========================================
# 3. 데이터 타입 최적화
# ==========================================

def optimize_memory(df):
    for col in df.columns:
        # 숫자형 데이터 최적화
        if df[col].dtype in ['int64', 'float64']:
            if df[col].dtype == 'int64':
                df[col] = pd.to_numeric(df[col], downcast='integer')
            else:
                df[col] = pd.to_numeric(df[col], downcast='float')
        
        # 문자열(object) 데이터 -> 범주형(category) 변환
        elif df[col].dtype == 'object':
            df[col] = df[col].astype('category')
    return df

train_df = optimize_memory(train_df)
test_df = optimize_memory(test_df)

# ==========================================
# 4. 모델 학습 설정
# ==========================================

predictor = TabularPredictor(
    label=target,
    eval_metric='roc_auc',
    problem_type='binary',
    path='ag_models_out_v16',
).fit(
    train_data=train_df,
    time_limit=10800,
    presets='best_quality',
    num_bag_folds=5,
    num_bag_sets=1,
    num_stack_levels=1,
    refit_full=True,
    dynamic_stacking=False,
    save_space=True,
)

# ==========================================
# 4. 예측 (Test Data 활용) - 최종 결과를 확률로 출력 (Positive 클래스에 대한 확률만 추출)
# ==========================================

pred_probs = predictor.predict_proba(test_df)
final_probs = pred_probs.iloc[:, 1]
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.11.14
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 25.2.0: Tue Nov 18 21:09:40 PST 2025; root:xnu-12377.61.12~1/RELEASE_ARM64_T6000
# CPU Count:          10
# Pytorch Version:    2.9.1
# CUDA Version:       CUDA is not available
# GPU Count:          WARNING: Exception was raised when calculating GPU count (AssertionError)
# Memory Avail:       4.09 GB / 16.00 GB (25.6%)
# Disk Space Avail:   152.82 GB / 460.43 GB (33.2%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# Beginning AutoGluon training ... Time limit = 10800s
# AutoGluon will save models to "/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_out_v16"
# Train Data Rows:    256351
# Train Data Columns: 79
# Label Column:       임신 성공 여부
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    4155.89 MB
# 	Train Data (Original)  Memory Usage: 48.66 MB (1.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 22 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 2): ['배아_이식_미도달', '배아_이식_여부']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 14 | ['시술 시기 코드', '시술 당시 나이', '시술 유형', '특정 시술 유형', '배란 유도 유형', ...]
# 		('float', [])    : 40 | ['임신 시도 또는 마지막 임신 경과 연수', '단일 배아 이식 여부', '착상 전 유전 검사 사용 여부', '착상 전 유전 진단 사용 여부', '총 생성 배아 수', ...]
# 		('int', [])      : 23 | ['배란 자극 여부', '남성 주 불임 원인', '남성 부 불임 원인', '여성 주 불임 원인', '여성 부 불임 원인', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 13 | ['시술 시기 코드', '시술 당시 나이', '특정 시술 유형', '배란 유도 유형', '배아 생성 주요 이유', ...]
# 		('float', [])     : 30 | ['임신 시도 또는 마지막 임신 경과 연수', '총 생성 배아 수', '미세주입된 난자 수', '미세주입에서 생성된 배아 수', '이식된 배아 수', ...]
# 		('int', [])       : 12 | ['총 시술 횟수', '클리닉 내 총 시술 횟수', 'IVF 시술 횟수', 'DI 시술 횟수', '총 임신 횟수', ...]
# 		('int', ['bool']) : 22 | ['시술 유형', '배란 자극 여부', '단일 배아 이식 여부', '착상 전 유전 검사 사용 여부', '착상 전 유전 진단 사용 여부', ...]
# 	0.5s = Fit runtime
# 	77 features in original data used to generate 77 features in processed data.
# 	Train Data (Processed) Memory Usage: 40.83 MB (1.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.5s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 7197.87s of the 10799.50s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.17%)
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/ray/_private/worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# 	0.7393	 = Validation score   (roc_auc)
# 	7.68s	 = Training   runtime
# 	2.27s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 7184.52s of the 10786.15s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.15%)
# 	0.7389	 = Validation score   (roc_auc)
# 	5.83s	 = Training   runtime
# 	1.55s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 7176.61s of the 10778.24s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/4.1 GB
# 	Warning: Reducing model 'n_estimators' from 300 -> 280 due to low memory. Expected memory usage reduced from 16.04% -> 15.0% of available memory...
# 	0.7299	 = Validation score   (roc_auc)
# 	11.84s	 = Training   runtime
# 	6.57s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 7157.82s of the 10759.45s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/3.6 GB
# 	Warning: Reducing model 'n_estimators' from 300 -> 243 due to low memory. Expected memory usage reduced from 18.46% -> 15.0% of available memory...
# 	0.7305	 = Validation score   (roc_auc)
# 	9.23s	 = Training   runtime
# 	5.84s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 7142.37s of the 10744.00s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 4 folds in parallel instead (Estimated 19.59% memory usage per fold, 78.36%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=19.59%)
# 	0.7395	 = Validation score   (roc_auc)
# 	438.9s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 6701.35s of the 10302.98s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/4.5 GB
# 	0.7319	 = Validation score   (roc_auc)
# 	8.74s	 = Training   runtime
# 	6.94s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 6685.24s of the 10286.86s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/4.1 GB
# 	Warning: Reducing model 'n_estimators' from 300 -> 276 due to low memory. Expected memory usage reduced from 16.3% -> 15.0% of available memory...
# 	0.7321	 = Validation score   (roc_auc)
# 	8.35s	 = Training   runtime
# 	6.46s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 6670.03s of the 10271.66s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=10.99%)
# 	0.7374	 = Validation score   (roc_auc)
# 	90.49s	 = Training   runtime
# 	1.02s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 6577.05s of the 10178.68s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.95%)
# 	0.7386	 = Validation score   (roc_auc)
# 	11.97s	 = Training   runtime
# 	1.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 6562.62s of the 10164.25s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.07%)
# 	0.7363	 = Validation score   (roc_auc)
# 	116.17s	 = Training   runtime
# 	1.48s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 6444.38s of the 10046.01s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.23%)
# 	0.7381	 = Validation score   (roc_auc)
# 	8.94s	 = Training   runtime
# 	2.32s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 6432.78s of the 10034.41s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=13.96%)
# 	0.7394	 = Validation score   (roc_auc)
# 	35.29s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 6395.42s of the 9997.05s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=4.96%)
# 	0.7372	 = Validation score   (roc_auc)
# 	158.81s	 = Training   runtime
# 	1.79s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 6234.72s of the 9836.35s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.89%)
# 	0.739	 = Validation score   (roc_auc)
# 	18.2s	 = Training   runtime
# 	7.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 6212.77s of the 9814.40s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.29%)
# 	0.7359	 = Validation score   (roc_auc)
# 	342.01s	 = Training   runtime
# 	2.17s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 5868.23s of the 9469.86s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.30% memory usage per fold, 65.18%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=16.30%)
# 	0.7392	 = Validation score   (roc_auc)
# 	112.73s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 5753.19s of the 9354.82s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=5.48%)
# 	0.7399	 = Validation score   (roc_auc)
# 	45.16s	 = Training   runtime
# 	12.4s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 5703.14s of the 9304.77s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.04%)
# 	0.7355	 = Validation score   (roc_auc)
# 	320.26s	 = Training   runtime
# 	2.48s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 5380.12s of the 8981.75s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=15.51%)
# 	0.7372	 = Validation score   (roc_auc)
# 	36.72s	 = Training   runtime
# 	3.37s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 5340.33s of the 8941.96s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/4.0 GB
# 	Warning: Reducing model 'n_estimators' from 300 -> 225 due to low memory. Expected memory usage reduced from 19.91% -> 15.0% of available memory...
# 	0.7219	 = Validation score   (roc_auc)
# 	41.47s	 = Training   runtime
# 	6.09s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 5292.32s of the 8893.95s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 4 folds in parallel instead (Estimated 19.18% memory usage per fold, 76.71%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=19.18%)
# 	0.7396	 = Validation score   (roc_auc)
# 	602.97s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 4686.90s of the 8288.53s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.49%)
# 	0.7376	 = Validation score   (roc_auc)
# 	54.23s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 4630.19s of the 8231.82s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.89%)
# 	0.7396	 = Validation score   (roc_auc)
# 	99.69s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 4528.05s of the 8129.68s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/6.3 GB
# 	Warning: Reducing model 'n_estimators' from 300 -> 176 due to low memory. Expected memory usage reduced from 25.49% -> 15.0% of available memory...
# 	0.7015	 = Validation score   (roc_auc)
# 	49.52s	 = Training   runtime
# 	5.74s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 4472.21s of the 8073.84s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.16%)
# 	0.7386	 = Validation score   (roc_auc)
# 	11.03s	 = Training   runtime
# 	3.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 4458.76s of the 8060.39s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.33%)
# 	0.7369	 = Validation score   (roc_auc)
# 	400.46s	 = Training   runtime
# 	4.19s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 4055.59s of the 7657.22s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.75%)
# 	0.739	 = Validation score   (roc_auc)
# 	18.8s	 = Training   runtime
# 	1.26s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 4034.15s of the 7635.78s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=4.05%)
# 	0.7348	 = Validation score   (roc_auc)
# 	527.95s	 = Training   runtime
# 	2.56s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 3503.69s of the 7105.32s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.14%)
# 	0.7389	 = Validation score   (roc_auc)
# 	6.93s	 = Training   runtime
# 	1.72s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 3494.04s of the 7095.67s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=4.81%)
# 	0.7379	 = Validation score   (roc_auc)
# 	496.94s	 = Training   runtime
# 	1.71s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 2995.07s of the 6596.70s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.42%)
# 	0.7392	 = Validation score   (roc_auc)
# 	115.6s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 2877.12s of the 6478.75s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.75%)
# 	0.7282	 = Validation score   (roc_auc)
# 	362.2s	 = Training   runtime
# 	3.81s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 2512.16s of the 6113.79s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.19%)
# 	0.7388	 = Validation score   (roc_auc)
# 	7.16s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 2502.63s of the 6104.26s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/5.9 GB
# 	0.7247	 = Validation score   (roc_auc)
# 	60.95s	 = Training   runtime
# 	7.62s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 2433.64s of the 6035.27s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=13.03%)
# 	0.7396	 = Validation score   (roc_auc)
# 	496.8s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 1935.12s of the 5536.75s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.40%)
# 	0.7373	 = Validation score   (roc_auc)
# 	308.52s	 = Training   runtime
# 	2.13s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 1623.78s of the 5225.40s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=4.17%)
# 	0.7374	 = Validation score   (roc_auc)
# 	61.84s	 = Training   runtime
# 	1.48s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 1559.26s of the 5160.89s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.33%)
# 	0.738	 = Validation score   (roc_auc)
# 	45.56s	 = Training   runtime
# 	15.98s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 1509.56s of the 5111.19s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.88%)
# 	0.7382	 = Validation score   (roc_auc)
# 	102.23s	 = Training   runtime
# 	1.07s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 1405.16s of the 5006.79s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.95%)
# 	0.7393	 = Validation score   (roc_auc)
# 	98.27s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 1304.60s of the 4906.23s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.66%)
# 	0.7366	 = Validation score   (roc_auc)
# 	91.88s	 = Training   runtime
# 	0.85s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 1210.87s of the 4812.50s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=6.57%)
# 	0.739	 = Validation score   (roc_auc)
# 	96.96s	 = Training   runtime
# 	50.99s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 1102.85s of the 4704.48s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/5.7 GB
# 	Warning: Reducing model 'n_estimators' from 300 -> 215 due to low memory. Expected memory usage reduced from 20.9% -> 15.0% of available memory...
# 	0.7085	 = Validation score   (roc_auc)
# 	58.32s	 = Training   runtime
# 	6.75s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 1037.23s of the 4638.86s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=14.85%)
# 	0.7393	 = Validation score   (roc_auc)
# 	215.08s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 820.33s of the 4421.96s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.21%)
# 	0.7374	 = Validation score   (roc_auc)
# 	420.55s	 = Training   runtime
# 	3.71s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41_BAG_L1 ... Training model for up to 396.75s of the 3998.38s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=3.76%)
# 	0.7376	 = Validation score   (roc_auc)
# 	171.03s	 = Training   runtime
# 	1.53s	 = Validation runtime
# Fitting model: XGBoost_r98_BAG_L1 ... Training model for up to 223.11s of the 3824.74s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.96%)
# 	0.7387	 = Validation score   (roc_auc)
# 	75.04s	 = Training   runtime
# 	4.48s	 = Validation runtime
# Fitting model: LightGBM_r15_BAG_L1 ... Training model for up to 144.95s of the 3746.58s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=4.95%)
# 	0.7391	 = Validation score   (roc_auc)
# 	12.39s	 = Training   runtime
# 	4.52s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 130.00s of the 3731.63s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=4.25%)
# 	0.715	 = Validation score   (roc_auc)
# 	103.11s	 = Training   runtime
# 	2.29s	 = Validation runtime
# Fitting model: CatBoost_r86_BAG_L1 ... Training model for up to 24.83s of the 3626.46s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=12.75%)
# 	0.7321	 = Validation score   (roc_auc)
# 	19.16s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37_BAG_L1 ... Training model for up to 3.66s of the 3605.29s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.66%)
# 	Time limit exceeded... Skipping NeuralNetFastAI_r37_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 719.79s of the 3599.57s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/5.2 GB
# 	Ensemble Weights: {'CatBoost_r137_BAG_L1': 0.16, 'LightGBM_r96_BAG_L1': 0.12, 'NeuralNetTorch_r22_BAG_L1': 0.08, 'NeuralNetFastAI_r102_BAG_L1': 0.08, 'NeuralNetTorch_r86_BAG_L1': 0.08, 'RandomForestEntr_BAG_L1': 0.04, 'NeuralNetFastAI_BAG_L1': 0.04, 'NeuralNetTorch_r79_BAG_L1': 0.04, 'XGBoost_r89_BAG_L1': 0.04, 'NeuralNetTorch_r30_BAG_L1': 0.04, 'ExtraTrees_r172_BAG_L1': 0.04, 'NeuralNetFastAI_r103_BAG_L1': 0.04, 'NeuralNetTorch_r14_BAG_L1': 0.04, 'LightGBM_r161_BAG_L1': 0.04, 'NeuralNetFastAI_r156_BAG_L1': 0.04, 'NeuralNetFastAI_r95_BAG_L1': 0.04, 'NeuralNetTorch_r41_BAG_L1': 0.04}
# 	0.7407	 = Validation score   (roc_auc)
# 	40.85s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting 108 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 3558.65s of the 3558.49s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.87%)
# 	0.7401	 = Validation score   (roc_auc)
# 	8.5s	 = Training   runtime
# 	0.99s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3547.74s of the 3547.59s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.32%)
# 	0.7401	 = Validation score   (roc_auc)
# 	6.55s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 3538.82s of the 3538.66s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/6.0 GB
# 	0.7361	 = Validation score   (roc_auc)
# 	80.6s	 = Training   runtime
# 	10.48s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 3447.03s of the 3446.87s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/4.8 GB
# 	0.7369	 = Validation score   (roc_auc)
# 	107.49s	 = Training   runtime
# 	10.92s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 3327.88s of the 3327.73s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 2 folds in parallel instead (Estimated 22.91% memory usage per fold, 45.82%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=5, gpus=0, memory=22.91%)
# 	0.7402	 = Validation score   (roc_auc)
# 	156.9s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 3168.74s of the 3168.58s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/5.2 GB
# 	0.7404	 = Validation score   (roc_auc)
# 	15.56s	 = Training   runtime
# 	9.73s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 3142.65s of the 3142.49s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/4.9 GB
# 	0.7402	 = Validation score   (roc_auc)
# 	16.52s	 = Training   runtime
# 	9.82s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 3115.55s of the 3115.39s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 2 folds in parallel instead (Estimated 20.06% memory usage per fold, 40.12%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=5, gpus=0, memory=20.06%)
# 	0.74	 = Validation score   (roc_auc)
# 	284.47s	 = Training   runtime
# 	1.28s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 2828.42s of the 2828.26s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=13.36%)
# 	0.7397	 = Validation score   (roc_auc)
# 	14.07s	 = Training   runtime
# 	1.33s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 2811.87s of the 2811.71s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.14%)
# 	0.7394	 = Validation score   (roc_auc)
# 	92.93s	 = Training   runtime
# 	2.23s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 2715.95s of the 2715.79s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.53%)
# 	0.7396	 = Validation score   (roc_auc)
# 	15.53s	 = Training   runtime
# 	1.83s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 2697.33s of the 2697.17s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.39% memory usage per fold, 69.56%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=17.39%)
# 	0.7402	 = Validation score   (roc_auc)
# 	17.91s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 2677.20s of the 2677.04s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.61%)
# 	0.7395	 = Validation score   (roc_auc)
# 	146.6s	 = Training   runtime
# 	2.74s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 2527.97s of the 2527.82s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.04%)
# 	0.7402	 = Validation score   (roc_auc)
# 	26.6s	 = Training   runtime
# 	5.24s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 2497.64s of the 2497.49s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.21% memory usage per fold, 64.85%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=16.21%)
# 	0.7398	 = Validation score   (roc_auc)
# 	309.63s	 = Training   runtime
# 	3.11s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 2185.19s of the 2185.03s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 4 folds in parallel instead (Estimated 18.42% memory usage per fold, 73.67%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=18.42%)
# 	0.7402	 = Validation score   (roc_auc)
# 	75.45s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 2106.79s of the 2106.64s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.33%)
# 	0.7403	 = Validation score   (roc_auc)
# 	33.19s	 = Training   runtime
# 	3.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 2070.01s of the 2069.85s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.48%)
# 	0.7381	 = Validation score   (roc_auc)
# 	216.85s	 = Training   runtime
# 	3.05s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 1850.45s of the 1850.30s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.83% memory usage per fold, 67.32%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=16.83%)
# 	0.7398	 = Validation score   (roc_auc)
# 	62.43s	 = Training   runtime
# 	2.52s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 1784.71s of the 1784.56s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/6.1 GB
# 	0.7371	 = Validation score   (roc_auc)
# 	120.71s	 = Training   runtime
# 	10.61s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 1652.65s of the 1652.49s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 4 folds in parallel instead (Estimated 19.67% memory usage per fold, 78.68%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=19.67%)
# 	0.7403	 = Validation score   (roc_auc)
# 	93.53s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 1556.33s of the 1556.17s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=15.00%)
# 	0.7401	 = Validation score   (roc_auc)
# 	60.91s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 1492.53s of the 1492.37s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.13% memory usage per fold, 68.51%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=17.13%)
# 	0.7403	 = Validation score   (roc_auc)
# 	81.05s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L2 ... Training model for up to 1408.68s of the 1408.52s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=1.2/6.6 GB
# 	Warning: Reducing model 'n_estimators' from 300 -> 292 due to low memory. Expected memory usage reduced from 15.36% -> 15.0% of available memory...
# 	0.7273	 = Validation score   (roc_auc)
# 	759.82s	 = Training   runtime
# 	10.83s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L2 ... Training model for up to 637.21s of the 637.05s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=15.01%)
# 	0.7398	 = Validation score   (roc_auc)
# 	20.45s	 = Training   runtime
# 	2.79s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 613.06s of the 612.90s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=14.24%)
# 	0.7399	 = Validation score   (roc_auc)
# 	385.88s	 = Training   runtime
# 	3.5s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L2 ... Training model for up to 224.43s of the 224.27s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=13.09%)
# 	0.7402	 = Validation score   (roc_auc)
# 	15.54s	 = Training   runtime
# 	1.3s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L2 ... Training model for up to 205.88s of the 205.72s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=7.76%)
# 	0.7355	 = Validation score   (roc_auc)
# 	164.32s	 = Training   runtime
# 	3.23s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L2 ... Training model for up to 38.43s of the 38.27s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=9.66%)
# 	0.7395	 = Validation score   (roc_auc)
# 	9.85s	 = Training   runtime
# 	1.35s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L2 ... Training model for up to 25.62s of the 25.46s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=8.54%)
# 	0.7382	 = Validation score   (roc_auc)
# 	20.16s	 = Training   runtime
# 	2.61s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 2.27s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/5.5 GB
# 	Ensemble Weights: {'ExtraTreesGini_BAG_L2': 0.2, 'ExtraTreesEntr_BAG_L2': 0.16, 'ExtraTrees_r42_BAG_L2': 0.16, 'NeuralNetTorch_r86_BAG_L1': 0.08, 'RandomForestEntr_BAG_L2': 0.08, 'LightGBM_r96_BAG_L1': 0.04, 'CatBoost_r137_BAG_L1': 0.04, 'NeuralNetTorch_r14_BAG_L1': 0.04, 'NeuralNetFastAI_r156_BAG_L1': 0.04, 'NeuralNetFastAI_r95_BAG_L1': 0.04, 'NeuralNetTorch_r41_BAG_L1': 0.04, 'RandomForestGini_BAG_L2': 0.04, 'XGBoost_r33_BAG_L2': 0.04}
# 	0.7424	 = Validation score   (roc_auc)
# 	54.31s	 = Training   runtime
# 	0.03s	 = Validation runtime
# AutoGluon training complete, total runtime = 10852.13s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 297.1 rows/s (51271 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/6.2 GB
# 	3.14s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/6.0 GB
# 	2.5s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	11.84s	 = Training   runtime
# 	6.57s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	9.23s	 = Training   runtime
# 	5.84s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	89.16s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	8.74s	 = Training   runtime
# 	6.94s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	8.35s	 = Training   runtime
# 	6.46s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.3 GB
# 	Stopping at the best epoch learned earlier - 12.
# 	49.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.92s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/4.3 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	54.91s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/4.4 GB
# 	6.35s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	8.14s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/4.4 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	69.43s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/4.8 GB
# 	11.89s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r191_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.4 GB
# 	Stopping at the best epoch learned earlier - 15.
# 	169.89s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	30.51s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/4.7 GB
# 	16.61s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/4.7 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	188.91s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	5.08s	 = Training   runtime
# Fitting model: ExtraTrees_r42_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	41.47s	 = Training   runtime
# 	6.09s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	103.34s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r102_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.5 GB
# 	Stopping at the best epoch learned earlier - 16.
# 	35.16s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	26.39s	 = Training   runtime
# Fitting model: RandomForest_r195_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	49.52s	 = Training   runtime
# 	5.74s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/4.4 GB
# 	6.79s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r145_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.4 GB
# 	Stopping at the best epoch learned earlier - 20.
# 	356.93s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	2.08s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/5.0 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	327.48s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/4.3 GB
# 	3.99s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/4.4 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	275.54s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r50_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	22.84s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r11_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.5 GB
# 	Stopping at the best epoch learned earlier - 2.
# 	48.5s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r194_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	1.77s	 = Training   runtime
# Fitting model: ExtraTrees_r172_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	60.95s	 = Training   runtime
# 	7.62s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r69_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	91.75s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r103_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.4 GB
# 	Stopping at the best epoch learned earlier - 27.
# 	217.9s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r14_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/4.7 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	16.73s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r161_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/4.8 GB
# 	34.6s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r143_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.8 GB
# No improvement since epoch 14: early stopping
# 	117.97s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r70_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	22.46s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r156_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.7 GB
# 	Stopping at the best epoch learned earlier - 16.
# 	34.32s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r196_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/4.6 GB
# 	58.95s	 = Training   runtime
# Fitting model: RandomForest_r39_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	58.32s	 = Training   runtime
# 	6.75s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r167_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	35.1s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r95_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.6 GB
# 	Stopping at the best epoch learned earlier - 20.
# 	342.61s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r41_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/4.6 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	75.26s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r98_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	19.67s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r15_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/4.8 GB
# 	7.64s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r158_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/4.7 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	84.9s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r86_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	5.1s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'CatBoost_r137_BAG_L1': 0.16, 'LightGBM_r96_BAG_L1': 0.12, 'NeuralNetTorch_r22_BAG_L1': 0.08, 'NeuralNetFastAI_r102_BAG_L1': 0.08, 'NeuralNetTorch_r86_BAG_L1': 0.08, 'RandomForestEntr_BAG_L1': 0.04, 'NeuralNetFastAI_BAG_L1': 0.04, 'NeuralNetTorch_r79_BAG_L1': 0.04, 'XGBoost_r89_BAG_L1': 0.04, 'NeuralNetTorch_r30_BAG_L1': 0.04, 'ExtraTrees_r172_BAG_L1': 0.04, 'NeuralNetFastAI_r103_BAG_L1': 0.04, 'NeuralNetTorch_r14_BAG_L1': 0.04, 'LightGBM_r161_BAG_L1': 0.04, 'NeuralNetFastAI_r156_BAG_L1': 0.04, 'NeuralNetFastAI_r95_BAG_L1': 0.04, 'NeuralNetTorch_r41_BAG_L1': 0.04}
# 	40.85s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/4.9 GB
# 	3.35s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/4.7 GB
# 	2.84s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	80.6s	 = Training   runtime
# 	10.48s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	107.49s	 = Training   runtime
# 	10.92s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=1.0/4.4 GB
# 	27.06s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	15.56s	 = Training   runtime
# 	9.73s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	16.52s	 = Training   runtime
# 	9.82s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.9/4.4 GB
# 	Stopping at the best epoch learned earlier - 13.
# 	66.53s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	2.96s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.7 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	17.74s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.6/4.8 GB
# 	8.18s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=1.0/4.9 GB
# 	4.09s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r79_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.9 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	31.49s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/4.9 GB
# 	10.82s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r191_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.9/4.8 GB
# 	Stopping at the best epoch learned earlier - 5.
# 	62.6s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=1.1/4.7 GB
# 	16.38s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/4.6 GB
# 	9.72s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r22_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.6 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	53.12s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=1.0/4.8 GB
# 	8.67s	 = Training   runtime
# Fitting model: ExtraTrees_r42_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	120.71s	 = Training   runtime
# 	10.61s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r137_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	17.93s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r102_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.9/4.4 GB
# 	Stopping at the best epoch learned earlier - 17.
# 	38.9s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r13_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=1.1/4.6 GB
# 	17.0s	 = Training   runtime
# Fitting model: RandomForest_r195_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	759.82s	 = Training   runtime
# 	10.83s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r188_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.6/4.3 GB
# 	10.4s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r145_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.9/4.4 GB
# 	Stopping at the best epoch learned earlier - 10.
# 	187.91s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r89_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0
# 	3.04s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r30_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/4.7 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	144.59s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r130_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.5/5.5 GB
# 	4.79s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_r86_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.4/5.5 GB
# /opt/anaconda3/envs/pregnancy/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:975: FutureWarning: The parameter `force_int_remainder_cols` is deprecated and will be removed in 1.9. It has no effect. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 	17.03s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'ExtraTreesGini_BAG_L2': 0.2, 'ExtraTreesEntr_BAG_L2': 0.16, 'ExtraTrees_r42_BAG_L2': 0.16, 'NeuralNetTorch_r86_BAG_L1': 0.08, 'RandomForestEntr_BAG_L2': 0.08, 'LightGBM_r96_BAG_L1': 0.04, 'CatBoost_r137_BAG_L1': 0.04, 'NeuralNetTorch_r14_BAG_L1': 0.04, 'NeuralNetFastAI_r156_BAG_L1': 0.04, 'NeuralNetFastAI_r95_BAG_L1': 0.04, 'NeuralNetTorch_r41_BAG_L1': 0.04, 'RandomForestGini_BAG_L2': 0.04, 'XGBoost_r33_BAG_L2': 0.04}
# 	54.31s	 = Training   runtime
# Refit complete, total runtime = 3876.24s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/admin/00 임신 예측/pregnancy-outcome-prediction-ai/Notebooks/ag_models_out_v16")

# %%
# --- 리더보드 출력 ---
lb = predictor.leaderboard(train_df, silent=True)
display(lb.head())
# Out:
#                            model  score_test  score_val eval_metric  \
# 0       RandomForest_r195_BAG_L1    0.998535   0.701480     roc_auc
# 1  RandomForest_r195_BAG_L1_FULL    0.998535        NaN     roc_auc
# 2   RandomForest_r39_BAG_L1_FULL    0.993876        NaN     roc_auc
# 3        RandomForest_r39_BAG_L1    0.993876   0.708516     roc_auc
# 4          ExtraTrees_r42_BAG_L1    0.957398   0.721879     roc_auc
#
#    pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0        1.785785       5.735097  49.515510                 1.785785
# 1        2.082848       5.735097  49.515510                 2.082848
# 2        2.131221       6.746926  58.322688                 2.131221
# 3        2.267808       6.746926  58.322688                 2.267808
# 4        1.353248       6.086441  41.468533                 1.353248
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                5.735097          49.515510            1       True
# 1                5.735097          49.515510            1       True
# 2                6.746926          58.322688            1       True
# 3                6.746926          58.322688            1       True
# 4                6.086441          41.468533            1       True
#
#    fit_order
# 0         24
# 1        106
# 2        125
# 3         43
# 4         20

# %%
# --- 제출 파일 생성 ---
submission = pd.read_csv('../Data/sample_submission.csv')
submission['probability'] = final_probs.values

# 현재 시간 가져오기 (예: 0206_1031)
now = datetime.now().strftime('%m%d_%H%M')
file_name = f"{now}_submission.csv"
submission.to_csv(file_name, index=False)

print(f"학습 및 예측이 완료되었습니다. 결과가 {file_name}에 저장되었습니다.")
# Out:
# 학습 및 예측이 완료되었습니다. 결과가 0211_1652_submission.csv에 저장되었습니다.

# %%
# --- 피처 중요도 ---
# fi = predictor.feature_importance(data=train_df.sample(n=min(5000, len(train_df)), random_state=42))
# fi.to_excel('fi16.xlsx')
